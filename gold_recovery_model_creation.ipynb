# %% [markdown]
# # Описание проекта
#
# Необходимо подготовить прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. В нашем распоряжении данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, make_scorer
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.dummy import DummyRegressor

# %%
train = pd.read_csv('/datasets/gold_recovery_train.csv')
test = pd.read_csv('/datasets/gold_recovery_test.csv')
full = pd.read_csv('/datasets/gold_recovery_full.csv')

# %%
full.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
# 3                    42.689819              68.347543             10.422762
# 4                    42.774141              66.927016             10.360302
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  ...  \
# 0              0.895447              16.904297              2.143149  ...
# 1              0.927452              16.634514              2.224930  ...
# 2              0.953716              16.208849              2.257889  ...
# 3              0.883763              16.532835              2.146849  ...
# 4              0.792826              16.525686              2.055292  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691
#
# [5 rows x 87 columns]

# %% [markdown]
# Получим информацию о тренировочном, тестовом и полном наборе данных.

# %%
for df in [train, test, full]:
    print('------------------------------------------------------------------------')
    df.info()
# Out:
# ------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16860 entries, 0 to 16859
# Data columns (total 87 columns):
# date                                                  16860 non-null object
# final.output.concentrate_ag                           16788 non-null float64
# final.output.concentrate_pb                           16788 non-null float64
# final.output.concentrate_sol                          16490 non-null float64
# final.output.concentrate_au                           16789 non-null float64
# final.output.recovery                                 15339 non-null float64
# final.output.tail_ag                                  16794 non-null float64
# final.output.tail_pb                                  16677 non-null float64
# final.output.tail_sol                                 16715 non-null float64
# final.output.tail_au                                  16794 non-null float64
# primary_cleaner.input.sulfate                         15553 non-null float64
# primary_cleaner.input.depressant                      15598 non-null float64
# primary_cleaner.input.feed_size                       16860 non-null float64
# primary_cleaner.input.xanthate                        15875 non-null float64
# primary_cleaner.output.concentrate_ag                 16778 non-null float64
# primary_cleaner.output.concentrate_pb                 16502 non-null float64
# primary_cleaner.output.concentrate_sol                16224 non-null float64
# primary_cleaner.output.concentrate_au                 16778 non-null float64
# primary_cleaner.output.tail_ag                        16777 non-null float64
# primary_cleaner.output.tail_pb                        16761 non-null float64
# primary_cleaner.output.tail_sol                       16579 non-null float64
# primary_cleaner.output.tail_au                        16777 non-null float64
# primary_cleaner.state.floatbank8_a_air                16820 non-null float64
# primary_cleaner.state.floatbank8_a_level              16827 non-null float64
# primary_cleaner.state.floatbank8_b_air                16820 non-null float64
# primary_cleaner.state.floatbank8_b_level              16833 non-null float64
# primary_cleaner.state.floatbank8_c_air                16822 non-null float64
# primary_cleaner.state.floatbank8_c_level              16833 non-null float64
# primary_cleaner.state.floatbank8_d_air                16821 non-null float64
# primary_cleaner.state.floatbank8_d_level              16833 non-null float64
# rougher.calculation.sulfate_to_au_concentrate         16833 non-null float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    16833 non-null float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    16833 non-null float64
# rougher.calculation.au_pb_ratio                       15618 non-null float64
# rougher.input.feed_ag                                 16778 non-null float64
# rougher.input.feed_pb                                 16632 non-null float64
# rougher.input.feed_rate                               16347 non-null float64
# rougher.input.feed_size                               16443 non-null float64
# rougher.input.feed_sol                                16568 non-null float64
# rougher.input.feed_au                                 16777 non-null float64
# rougher.input.floatbank10_sulfate                     15816 non-null float64
# rougher.input.floatbank10_xanthate                    16514 non-null float64
# rougher.input.floatbank11_sulfate                     16237 non-null float64
# rougher.input.floatbank11_xanthate                    14956 non-null float64
# rougher.output.concentrate_ag                         16778 non-null float64
# rougher.output.concentrate_pb                         16778 non-null float64
# rougher.output.concentrate_sol                        16698 non-null float64
# rougher.output.concentrate_au                         16778 non-null float64
# rougher.output.recovery                               14287 non-null float64
# rougher.output.tail_ag                                14610 non-null float64
# rougher.output.tail_pb                                16778 non-null float64
# rougher.output.tail_sol                               14611 non-null float64
# rougher.output.tail_au                                14611 non-null float64
# rougher.state.floatbank10_a_air                       16807 non-null float64
# rougher.state.floatbank10_a_level                     16807 non-null float64
# rougher.state.floatbank10_b_air                       16807 non-null float64
# rougher.state.floatbank10_b_level                     16807 non-null float64
# rougher.state.floatbank10_c_air                       16807 non-null float64
# rougher.state.floatbank10_c_level                     16814 non-null float64
# rougher.state.floatbank10_d_air                       16802 non-null float64
# rougher.state.floatbank10_d_level                     16809 non-null float64
# rougher.state.floatbank10_e_air                       16257 non-null float64
# rougher.state.floatbank10_e_level                     16809 non-null float64
# rougher.state.floatbank10_f_air                       16802 non-null float64
# rougher.state.floatbank10_f_level                     16802 non-null float64
# secondary_cleaner.output.tail_ag                      16776 non-null float64
# secondary_cleaner.output.tail_pb                      16764 non-null float64
# secondary_cleaner.output.tail_sol                     14874 non-null float64
# secondary_cleaner.output.tail_au                      16778 non-null float64
# secondary_cleaner.state.floatbank2_a_air              16497 non-null float64
# secondary_cleaner.state.floatbank2_a_level            16751 non-null float64
# secondary_cleaner.state.floatbank2_b_air              16705 non-null float64
# secondary_cleaner.state.floatbank2_b_level            16748 non-null float64
# secondary_cleaner.state.floatbank3_a_air              16763 non-null float64
# secondary_cleaner.state.floatbank3_a_level            16747 non-null float64
# secondary_cleaner.state.floatbank3_b_air              16752 non-null float64
# secondary_cleaner.state.floatbank3_b_level            16750 non-null float64
# secondary_cleaner.state.floatbank4_a_air              16731 non-null float64
# secondary_cleaner.state.floatbank4_a_level            16747 non-null float64
# secondary_cleaner.state.floatbank4_b_air              16768 non-null float64
# secondary_cleaner.state.floatbank4_b_level            16767 non-null float64
# secondary_cleaner.state.floatbank5_a_air              16775 non-null float64
# secondary_cleaner.state.floatbank5_a_level            16775 non-null float64
# secondary_cleaner.state.floatbank5_b_air              16775 non-null float64
# secondary_cleaner.state.floatbank5_b_level            16776 non-null float64
# secondary_cleaner.state.floatbank6_a_air              16757 non-null float64
# secondary_cleaner.state.floatbank6_a_level            16775 non-null float64
# dtypes: float64(86), object(1)
# memory usage: 11.2+ MB
# ------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5856 entries, 0 to 5855
# Data columns (total 53 columns):
# date                                          5856 non-null object
# primary_cleaner.input.sulfate                 5554 non-null float64
# primary_cleaner.input.depressant              5572 non-null float64
# primary_cleaner.input.feed_size               5856 non-null float64
# primary_cleaner.input.xanthate                5690 non-null float64
# primary_cleaner.state.floatbank8_a_air        5840 non-null float64
# primary_cleaner.state.floatbank8_a_level      5840 non-null float64
# primary_cleaner.state.floatbank8_b_air        5840 non-null float64
# primary_cleaner.state.floatbank8_b_level      5840 non-null float64
# primary_cleaner.state.floatbank8_c_air        5840 non-null float64
# primary_cleaner.state.floatbank8_c_level      5840 non-null float64
# primary_cleaner.state.floatbank8_d_air        5840 non-null float64
# primary_cleaner.state.floatbank8_d_level      5840 non-null float64
# rougher.input.feed_ag                         5840 non-null float64
# rougher.input.feed_pb                         5840 non-null float64
# rougher.input.feed_rate                       5816 non-null float64
# rougher.input.feed_size                       5834 non-null float64
# rougher.input.feed_sol                        5789 non-null float64
# rougher.input.feed_au                         5840 non-null float64
# rougher.input.floatbank10_sulfate             5599 non-null float64
# rougher.input.floatbank10_xanthate            5733 non-null float64
# rougher.input.floatbank11_sulfate             5801 non-null float64
# rougher.input.floatbank11_xanthate            5503 non-null float64
# rougher.state.floatbank10_a_air               5839 non-null float64
# rougher.state.floatbank10_a_level             5840 non-null float64
# rougher.state.floatbank10_b_air               5839 non-null float64
# rougher.state.floatbank10_b_level             5840 non-null float64
# rougher.state.floatbank10_c_air               5839 non-null float64
# rougher.state.floatbank10_c_level             5840 non-null float64
# rougher.state.floatbank10_d_air               5839 non-null float64
# rougher.state.floatbank10_d_level             5840 non-null float64
# rougher.state.floatbank10_e_air               5839 non-null float64
# rougher.state.floatbank10_e_level             5840 non-null float64
# rougher.state.floatbank10_f_air               5839 non-null float64
# rougher.state.floatbank10_f_level             5840 non-null float64
# secondary_cleaner.state.floatbank2_a_air      5836 non-null float64
# secondary_cleaner.state.floatbank2_a_level    5840 non-null float64
# secondary_cleaner.state.floatbank2_b_air      5833 non-null float64
# secondary_cleaner.state.floatbank2_b_level    5840 non-null float64
# secondary_cleaner.state.floatbank3_a_air      5822 non-null float64
# secondary_cleaner.state.floatbank3_a_level    5840 non-null float64
# secondary_cleaner.state.floatbank3_b_air      5840 non-null float64
# secondary_cleaner.state.floatbank3_b_level    5840 non-null float64
# secondary_cleaner.state.floatbank4_a_air      5840 non-null float64
# secondary_cleaner.state.floatbank4_a_level    5840 non-null float64
# secondary_cleaner.state.floatbank4_b_air      5840 non-null float64
# secondary_cleaner.state.floatbank4_b_level    5840 non-null float64
# secondary_cleaner.state.floatbank5_a_air      5840 non-null float64
# secondary_cleaner.state.floatbank5_a_level    5840 non-null float64
# secondary_cleaner.state.floatbank5_b_air      5840 non-null float64
# secondary_cleaner.state.floatbank5_b_level    5840 non-null float64
# secondary_cleaner.state.floatbank6_a_air      5840 non-null float64
# secondary_cleaner.state.floatbank6_a_level    5840 non-null float64
# dtypes: float64(52), object(1)
# memory usage: 2.4+ MB
# ------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22716 entries, 0 to 22715
# Data columns (total 87 columns):
# date                                                  22716 non-null object
# final.output.concentrate_ag                           22627 non-null float64
# final.output.concentrate_pb                           22629 non-null float64
# final.output.concentrate_sol                          22331 non-null float64
# final.output.concentrate_au                           22630 non-null float64
# final.output.recovery                                 20753 non-null float64
# final.output.tail_ag                                  22633 non-null float64
# final.output.tail_pb                                  22516 non-null float64
# final.output.tail_sol                                 22445 non-null float64
# final.output.tail_au                                  22635 non-null float64
# primary_cleaner.input.sulfate                         21107 non-null float64
# primary_cleaner.input.depressant                      21170 non-null float64
# primary_cleaner.input.feed_size                       22716 non-null float64
# primary_cleaner.input.xanthate                        21565 non-null float64
# primary_cleaner.output.concentrate_ag                 22618 non-null float64
# primary_cleaner.output.concentrate_pb                 22268 non-null float64
# primary_cleaner.output.concentrate_sol                21918 non-null float64
# primary_cleaner.output.concentrate_au                 22618 non-null float64
# primary_cleaner.output.tail_ag                        22614 non-null float64
# primary_cleaner.output.tail_pb                        22594 non-null float64
# primary_cleaner.output.tail_sol                       22365 non-null float64
# primary_cleaner.output.tail_au                        22617 non-null float64
# primary_cleaner.state.floatbank8_a_air                22660 non-null float64
# primary_cleaner.state.floatbank8_a_level              22667 non-null float64
# primary_cleaner.state.floatbank8_b_air                22660 non-null float64
# primary_cleaner.state.floatbank8_b_level              22673 non-null float64
# primary_cleaner.state.floatbank8_c_air                22662 non-null float64
# primary_cleaner.state.floatbank8_c_level              22673 non-null float64
# primary_cleaner.state.floatbank8_d_air                22661 non-null float64
# primary_cleaner.state.floatbank8_d_level              22673 non-null float64
# rougher.calculation.sulfate_to_au_concentrate         22672 non-null float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    22672 non-null float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    22672 non-null float64
# rougher.calculation.au_pb_ratio                       21089 non-null float64
# rougher.input.feed_ag                                 22618 non-null float64
# rougher.input.feed_pb                                 22472 non-null float64
# rougher.input.feed_rate                               22163 non-null float64
# rougher.input.feed_size                               22277 non-null float64
# rougher.input.feed_sol                                22357 non-null float64
# rougher.input.feed_au                                 22617 non-null float64
# rougher.input.floatbank10_sulfate                     21415 non-null float64
# rougher.input.floatbank10_xanthate                    22247 non-null float64
# rougher.input.floatbank11_sulfate                     22038 non-null float64
# rougher.input.floatbank11_xanthate                    20459 non-null float64
# rougher.output.concentrate_ag                         22618 non-null float64
# rougher.output.concentrate_pb                         22618 non-null float64
# rougher.output.concentrate_sol                        22526 non-null float64
# rougher.output.concentrate_au                         22618 non-null float64
# rougher.output.recovery                               19597 non-null float64
# rougher.output.tail_ag                                19979 non-null float64
# rougher.output.tail_pb                                22618 non-null float64
# rougher.output.tail_sol                               19980 non-null float64
# rougher.output.tail_au                                19980 non-null float64
# rougher.state.floatbank10_a_air                       22646 non-null float64
# rougher.state.floatbank10_a_level                     22647 non-null float64
# rougher.state.floatbank10_b_air                       22646 non-null float64
# rougher.state.floatbank10_b_level                     22647 non-null float64
# rougher.state.floatbank10_c_air                       22646 non-null float64
# rougher.state.floatbank10_c_level                     22654 non-null float64
# rougher.state.floatbank10_d_air                       22641 non-null float64
# rougher.state.floatbank10_d_level                     22649 non-null float64
# rougher.state.floatbank10_e_air                       22096 non-null float64
# rougher.state.floatbank10_e_level                     22649 non-null float64
# rougher.state.floatbank10_f_air                       22641 non-null float64
# rougher.state.floatbank10_f_level                     22642 non-null float64
# secondary_cleaner.output.tail_ag                      22616 non-null float64
# secondary_cleaner.output.tail_pb                      22600 non-null float64
# secondary_cleaner.output.tail_sol                     20501 non-null float64
# secondary_cleaner.output.tail_au                      22618 non-null float64
# secondary_cleaner.state.floatbank2_a_air              22333 non-null float64
# secondary_cleaner.state.floatbank2_a_level            22591 non-null float64
# secondary_cleaner.state.floatbank2_b_air              22538 non-null float64
# secondary_cleaner.state.floatbank2_b_level            22588 non-null float64
# secondary_cleaner.state.floatbank3_a_air              22585 non-null float64
# secondary_cleaner.state.floatbank3_a_level            22587 non-null float64
# secondary_cleaner.state.floatbank3_b_air              22592 non-null float64
# secondary_cleaner.state.floatbank3_b_level            22590 non-null float64
# secondary_cleaner.state.floatbank4_a_air              22571 non-null float64
# secondary_cleaner.state.floatbank4_a_level            22587 non-null float64
# secondary_cleaner.state.floatbank4_b_air              22608 non-null float64
# secondary_cleaner.state.floatbank4_b_level            22607 non-null float64
# secondary_cleaner.state.floatbank5_a_air              22615 non-null float64
# secondary_cleaner.state.floatbank5_a_level            22615 non-null float64
# secondary_cleaner.state.floatbank5_b_air              22615 non-null float64
# secondary_cleaner.state.floatbank5_b_level            22616 non-null float64
# secondary_cleaner.state.floatbank6_a_air              22597 non-null float64
# secondary_cleaner.state.floatbank6_a_level            22615 non-null float64
# dtypes: float64(86), object(1)
# memory usage: 15.1+ MB

# %% [markdown]
# В тренировочном наборе представленно 87 столбцов и 16860 строк и почти во всех столбцах присутствуют пропуски. Необходимо разобраться какие данные нам понадобятся для построения модели, а какие можно откинуть.
#
# В тестовом наборе данных всего 53 столбца и 5856 строк. Необходимо понять почему количество признаков в тестовых данных меньше, чем в тренировочных.
#
# В полном наборе присутствуют 87 столбцов и 22716 строк.

# %% [markdown]
# ### Расчет эффективности обогащения золота

# %% [markdown]
# Напишем функцию для расчета эффективности обогащения золота при флотации и сравним полученные данные с теми, которые записаны в тренировочной выборке, подсчитав МАЕ.

# %%
def recovery(row):
    C = row['rougher.output.concentrate_au'] #доля золота в концентрате после флотации
    F = row['rougher.input.feed_au'] #доля золота в сырье до флотации
    T = row['rougher.output.tail_au'] #доля золота в отвальных хвостах после флотации
    if F != 0:
        return C * (F - T) / (F * (C - T)) * 100
    else:
        return row['rougher.output.recovery']

# %%
rougher_out_recovery = train[train['rougher.output.recovery'] == train['rougher.output.recovery']].apply(recovery, axis=1)

# %%
print('MAE:', mean_absolute_error(
    train.loc[train['rougher.output.recovery'] == train['rougher.output.recovery'], 'rougher.output.recovery'],
    rougher_out_recovery)
     )
# Out:
# MAE: 9.444891926100695e-15

# %% [markdown]
# Полученное значение МАЕ близко к нулю, это говорит о том, что имеющиеся данные полностью соответствуют тем, которые мы получили при расчете эффекцивности обогащения по формуле.

# %% [markdown]
# ### Изучение признаков отсутствующих в тестовой выборке

# %% [markdown]
# Выясним какие признаки отсутствуют в тестовой выборке и почему.

# %%
columns = list(train.columns[train.columns.isin(test.columns) != True])
#columns = train.columns.where(train.columns.isin(test.columns))
columns
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'rougher.output.tail_au',
#  'secondary_cleaner.output.tail_ag',
#  'secondary_cleaner.output.tail_pb',
#  'secondary_cleaner.output.tail_sol',
#  'secondary_cleaner.output.tail_au']

# %% [markdown]
# Как можно заметить из списка выше, в тестовой выборке отсутствуют признаки только с типом `output`, то есть с параметрами продукта на выходе из этапов обогащения и очистки золотосодержащей руды. Отсустсвуют они, потому что данные по этим признакам получаются только на реальных данных и по историческим данным их не построить. То есть в списке представлены онлайн-признаки.

# %% [markdown]
# Удалим строки, в которых есть пропуски в целевых колонках.

# %%
date_del = full.loc[full['final.output.recovery'].isnull() & full['rougher.output.recovery'].isnull()]['date']
train = train.dropna(subset=['final.output.recovery', 'rougher.output.recovery'], axis=0)
test = test.loc[test['date'].isin(date_del) == False]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14149 entries, 0 to 16859
# Data columns (total 87 columns):
# date                                                  14149 non-null object
# final.output.concentrate_ag                           14148 non-null float64
# final.output.concentrate_pb                           14148 non-null float64
# final.output.concentrate_sol                          13938 non-null float64
# final.output.concentrate_au                           14149 non-null float64
# final.output.recovery                                 14149 non-null float64
# final.output.tail_ag                                  14149 non-null float64
# final.output.tail_pb                                  14049 non-null float64
# final.output.tail_sol                                 14144 non-null float64
# final.output.tail_au                                  14149 non-null float64
# primary_cleaner.input.sulfate                         14129 non-null float64
# primary_cleaner.input.depressant                      14117 non-null float64
# primary_cleaner.input.feed_size                       14149 non-null float64
# primary_cleaner.input.xanthate                        14049 non-null float64
# primary_cleaner.output.concentrate_ag                 14149 non-null float64
# primary_cleaner.output.concentrate_pb                 14063 non-null float64
# primary_cleaner.output.concentrate_sol                13863 non-null float64
# primary_cleaner.output.concentrate_au                 14149 non-null float64
# primary_cleaner.output.tail_ag                        14148 non-null float64
# primary_cleaner.output.tail_pb                        14134 non-null float64
# primary_cleaner.output.tail_sol                       14103 non-null float64
# primary_cleaner.output.tail_au                        14149 non-null float64
# primary_cleaner.state.floatbank8_a_air                14145 non-null float64
# primary_cleaner.state.floatbank8_a_level              14148 non-null float64
# primary_cleaner.state.floatbank8_b_air                14145 non-null float64
# primary_cleaner.state.floatbank8_b_level              14148 non-null float64
# primary_cleaner.state.floatbank8_c_air                14147 non-null float64
# primary_cleaner.state.floatbank8_c_level              14148 non-null float64
# primary_cleaner.state.floatbank8_d_air                14146 non-null float64
# primary_cleaner.state.floatbank8_d_level              14148 non-null float64
# rougher.calculation.sulfate_to_au_concentrate         14148 non-null float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    14148 non-null float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    14148 non-null float64
# rougher.calculation.au_pb_ratio                       14149 non-null float64
# rougher.input.feed_ag                                 14149 non-null float64
# rougher.input.feed_pb                                 14049 non-null float64
# rougher.input.feed_rate                               14141 non-null float64
# rougher.input.feed_size                               14005 non-null float64
# rougher.input.feed_sol                                14071 non-null float64
# rougher.input.feed_au                                 14149 non-null float64
# rougher.input.floatbank10_sulfate                     14120 non-null float64
# rougher.input.floatbank10_xanthate                    14141 non-null float64
# rougher.input.floatbank11_sulfate                     14113 non-null float64
# rougher.input.floatbank11_xanthate                    13721 non-null float64
# rougher.output.concentrate_ag                         14149 non-null float64
# rougher.output.concentrate_pb                         14149 non-null float64
# rougher.output.concentrate_sol                        14127 non-null float64
# rougher.output.concentrate_au                         14149 non-null float64
# rougher.output.recovery                               14149 non-null float64
# rougher.output.tail_ag                                14148 non-null float64
# rougher.output.tail_pb                                14149 non-null float64
# rougher.output.tail_sol                               14149 non-null float64
# rougher.output.tail_au                                14149 non-null float64
# rougher.state.floatbank10_a_air                       14148 non-null float64
# rougher.state.floatbank10_a_level                     14148 non-null float64
# rougher.state.floatbank10_b_air                       14148 non-null float64
# rougher.state.floatbank10_b_level                     14148 non-null float64
# rougher.state.floatbank10_c_air                       14148 non-null float64
# rougher.state.floatbank10_c_level                     14148 non-null float64
# rougher.state.floatbank10_d_air                       14149 non-null float64
# rougher.state.floatbank10_d_level                     14149 non-null float64
# rougher.state.floatbank10_e_air                       13713 non-null float64
# rougher.state.floatbank10_e_level                     14149 non-null float64
# rougher.state.floatbank10_f_air                       14149 non-null float64
# rougher.state.floatbank10_f_level                     14149 non-null float64
# secondary_cleaner.output.tail_ag                      14147 non-null float64
# secondary_cleaner.output.tail_pb                      14139 non-null float64
# secondary_cleaner.output.tail_sol                     12544 non-null float64
# secondary_cleaner.output.tail_au                      14149 non-null float64
# secondary_cleaner.state.floatbank2_a_air              13932 non-null float64
# secondary_cleaner.state.floatbank2_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank2_b_air              14128 non-null float64
# secondary_cleaner.state.floatbank2_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank3_a_air              14145 non-null float64
# secondary_cleaner.state.floatbank3_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank3_b_air              14148 non-null float64
# secondary_cleaner.state.floatbank3_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank4_a_air              14143 non-null float64
# secondary_cleaner.state.floatbank4_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank4_b_air              14148 non-null float64
# secondary_cleaner.state.floatbank4_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank5_a_air              14148 non-null float64
# secondary_cleaner.state.floatbank5_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank5_b_air              14148 non-null float64
# secondary_cleaner.state.floatbank5_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank6_a_air              14147 non-null float64
# secondary_cleaner.state.floatbank6_a_level            14148 non-null float64
# dtypes: float64(86), object(1)
# memory usage: 9.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5434 entries, 0 to 5855
# Data columns (total 53 columns):
# date                                          5434 non-null object
# primary_cleaner.input.sulfate                 5426 non-null float64
# primary_cleaner.input.depressant              5427 non-null float64
# primary_cleaner.input.feed_size               5434 non-null float64
# primary_cleaner.input.xanthate                5427 non-null float64
# primary_cleaner.state.floatbank8_a_air        5434 non-null float64
# primary_cleaner.state.floatbank8_a_level      5434 non-null float64
# primary_cleaner.state.floatbank8_b_air        5434 non-null float64
# primary_cleaner.state.floatbank8_b_level      5434 non-null float64
# primary_cleaner.state.floatbank8_c_air        5434 non-null float64
# primary_cleaner.state.floatbank8_c_level      5434 non-null float64
# primary_cleaner.state.floatbank8_d_air        5434 non-null float64
# primary_cleaner.state.floatbank8_d_level      5434 non-null float64
# rougher.input.feed_ag                         5434 non-null float64
# rougher.input.feed_pb                         5434 non-null float64
# rougher.input.feed_rate                       5431 non-null float64
# rougher.input.feed_size                       5433 non-null float64
# rougher.input.feed_sol                        5401 non-null float64
# rougher.input.feed_au                         5434 non-null float64
# rougher.input.floatbank10_sulfate             5427 non-null float64
# rougher.input.floatbank10_xanthate            5432 non-null float64
# rougher.input.floatbank11_sulfate             5423 non-null float64
# rougher.input.floatbank11_xanthate            5400 non-null float64
# rougher.state.floatbank10_a_air               5434 non-null float64
# rougher.state.floatbank10_a_level             5434 non-null float64
# rougher.state.floatbank10_b_air               5434 non-null float64
# rougher.state.floatbank10_b_level             5434 non-null float64
# rougher.state.floatbank10_c_air               5434 non-null float64
# rougher.state.floatbank10_c_level             5434 non-null float64
# rougher.state.floatbank10_d_air               5434 non-null float64
# rougher.state.floatbank10_d_level             5434 non-null float64
# rougher.state.floatbank10_e_air               5434 non-null float64
# rougher.state.floatbank10_e_level             5434 non-null float64
# rougher.state.floatbank10_f_air               5434 non-null float64
# rougher.state.floatbank10_f_level             5434 non-null float64
# secondary_cleaner.state.floatbank2_a_air      5431 non-null float64
# secondary_cleaner.state.floatbank2_a_level    5434 non-null float64
# secondary_cleaner.state.floatbank2_b_air      5431 non-null float64
# secondary_cleaner.state.floatbank2_b_level    5434 non-null float64
# secondary_cleaner.state.floatbank3_a_air      5423 non-null float64
# secondary_cleaner.state.floatbank3_a_level    5434 non-null float64
# secondary_cleaner.state.floatbank3_b_air      5434 non-null float64
# secondary_cleaner.state.floatbank3_b_level    5434 non-null float64
# secondary_cleaner.state.floatbank4_a_air      5434 non-null float64
# secondary_cleaner.state.floatbank4_a_level    5434 non-null float64
# secondary_cleaner.state.floatbank4_b_air      5434 non-null float64
# secondary_cleaner.state.floatbank4_b_level    5434 non-null float64
# secondary_cleaner.state.floatbank5_a_air      5434 non-null float64
# secondary_cleaner.state.floatbank5_a_level    5434 non-null float64
# secondary_cleaner.state.floatbank5_b_air      5434 non-null float64
# secondary_cleaner.state.floatbank5_b_level    5434 non-null float64
# secondary_cleaner.state.floatbank6_a_air      5434 non-null float64
# secondary_cleaner.state.floatbank6_a_level    5434 non-null float64
# dtypes: float64(52), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# Произведем предобработку данных, заполнив пропуски во всех выборках значениями элементов, стоящих перед пропущенными. Мы можем так сделать, потому что такие значения находятся рядом по временной шкале и не должны сильно отличаться.

# %%
train = train.ffill(axis=0)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14149 entries, 0 to 16859
# Data columns (total 87 columns):
# date                                                  14149 non-null object
# final.output.concentrate_ag                           14149 non-null float64
# final.output.concentrate_pb                           14149 non-null float64
# final.output.concentrate_sol                          14149 non-null float64
# final.output.concentrate_au                           14149 non-null float64
# final.output.recovery                                 14149 non-null float64
# final.output.tail_ag                                  14149 non-null float64
# final.output.tail_pb                                  14149 non-null float64
# final.output.tail_sol                                 14149 non-null float64
# final.output.tail_au                                  14149 non-null float64
# primary_cleaner.input.sulfate                         14149 non-null float64
# primary_cleaner.input.depressant                      14149 non-null float64
# primary_cleaner.input.feed_size                       14149 non-null float64
# primary_cleaner.input.xanthate                        14149 non-null float64
# primary_cleaner.output.concentrate_ag                 14149 non-null float64
# primary_cleaner.output.concentrate_pb                 14149 non-null float64
# primary_cleaner.output.concentrate_sol                14149 non-null float64
# primary_cleaner.output.concentrate_au                 14149 non-null float64
# primary_cleaner.output.tail_ag                        14149 non-null float64
# primary_cleaner.output.tail_pb                        14149 non-null float64
# primary_cleaner.output.tail_sol                       14149 non-null float64
# primary_cleaner.output.tail_au                        14149 non-null float64
# primary_cleaner.state.floatbank8_a_air                14149 non-null float64
# primary_cleaner.state.floatbank8_a_level              14149 non-null float64
# primary_cleaner.state.floatbank8_b_air                14149 non-null float64
# primary_cleaner.state.floatbank8_b_level              14149 non-null float64
# primary_cleaner.state.floatbank8_c_air                14149 non-null float64
# primary_cleaner.state.floatbank8_c_level              14149 non-null float64
# primary_cleaner.state.floatbank8_d_air                14149 non-null float64
# primary_cleaner.state.floatbank8_d_level              14149 non-null float64
# rougher.calculation.sulfate_to_au_concentrate         14149 non-null float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    14149 non-null float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    14149 non-null float64
# rougher.calculation.au_pb_ratio                       14149 non-null float64
# rougher.input.feed_ag                                 14149 non-null float64
# rougher.input.feed_pb                                 14149 non-null float64
# rougher.input.feed_rate                               14149 non-null float64
# rougher.input.feed_size                               14149 non-null float64
# rougher.input.feed_sol                                14149 non-null float64
# rougher.input.feed_au                                 14149 non-null float64
# rougher.input.floatbank10_sulfate                     14149 non-null float64
# rougher.input.floatbank10_xanthate                    14149 non-null float64
# rougher.input.floatbank11_sulfate                     14149 non-null float64
# rougher.input.floatbank11_xanthate                    14149 non-null float64
# rougher.output.concentrate_ag                         14149 non-null float64
# rougher.output.concentrate_pb                         14149 non-null float64
# rougher.output.concentrate_sol                        14149 non-null float64
# rougher.output.concentrate_au                         14149 non-null float64
# rougher.output.recovery                               14149 non-null float64
# rougher.output.tail_ag                                14149 non-null float64
# rougher.output.tail_pb                                14149 non-null float64
# rougher.output.tail_sol                               14149 non-null float64
# rougher.output.tail_au                                14149 non-null float64
# rougher.state.floatbank10_a_air                       14149 non-null float64
# rougher.state.floatbank10_a_level                     14149 non-null float64
# rougher.state.floatbank10_b_air                       14149 non-null float64
# rougher.state.floatbank10_b_level                     14149 non-null float64
# rougher.state.floatbank10_c_air                       14149 non-null float64
# rougher.state.floatbank10_c_level                     14149 non-null float64
# rougher.state.floatbank10_d_air                       14149 non-null float64
# rougher.state.floatbank10_d_level                     14149 non-null float64
# rougher.state.floatbank10_e_air                       14149 non-null float64
# rougher.state.floatbank10_e_level                     14149 non-null float64
# rougher.state.floatbank10_f_air                       14149 non-null float64
# rougher.state.floatbank10_f_level                     14149 non-null float64
# secondary_cleaner.output.tail_ag                      14149 non-null float64
# secondary_cleaner.output.tail_pb                      14149 non-null float64
# secondary_cleaner.output.tail_sol                     14149 non-null float64
# secondary_cleaner.output.tail_au                      14149 non-null float64
# secondary_cleaner.state.floatbank2_a_air              14149 non-null float64
# secondary_cleaner.state.floatbank2_a_level            14149 non-null float64
# secondary_cleaner.state.floatbank2_b_air              14149 non-null float64
# secondary_cleaner.state.floatbank2_b_level            14149 non-null float64
# secondary_cleaner.state.floatbank3_a_air              14149 non-null float64
# secondary_cleaner.state.floatbank3_a_level            14149 non-null float64
# secondary_cleaner.state.floatbank3_b_air              14149 non-null float64
# secondary_cleaner.state.floatbank3_b_level            14149 non-null float64
# secondary_cleaner.state.floatbank4_a_air              14149 non-null float64
# secondary_cleaner.state.floatbank4_a_level            14149 non-null float64
# secondary_cleaner.state.floatbank4_b_air              14149 non-null float64
# secondary_cleaner.state.floatbank4_b_level            14149 non-null float64
# secondary_cleaner.state.floatbank5_a_air              14149 non-null float64
# secondary_cleaner.state.floatbank5_a_level            14149 non-null float64
# secondary_cleaner.state.floatbank5_b_air              14149 non-null float64
# secondary_cleaner.state.floatbank5_b_level            14149 non-null float64
# secondary_cleaner.state.floatbank6_a_air              14149 non-null float64
# secondary_cleaner.state.floatbank6_a_level            14149 non-null float64
# dtypes: float64(86), object(1)
# memory usage: 9.5+ MB

# %%
test = test.ffill(axis=0)
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5434 entries, 0 to 5855
# Data columns (total 53 columns):
# date                                          5434 non-null object
# primary_cleaner.input.sulfate                 5434 non-null float64
# primary_cleaner.input.depressant              5434 non-null float64
# primary_cleaner.input.feed_size               5434 non-null float64
# primary_cleaner.input.xanthate                5434 non-null float64
# primary_cleaner.state.floatbank8_a_air        5434 non-null float64
# primary_cleaner.state.floatbank8_a_level      5434 non-null float64
# primary_cleaner.state.floatbank8_b_air        5434 non-null float64
# primary_cleaner.state.floatbank8_b_level      5434 non-null float64
# primary_cleaner.state.floatbank8_c_air        5434 non-null float64
# primary_cleaner.state.floatbank8_c_level      5434 non-null float64
# primary_cleaner.state.floatbank8_d_air        5434 non-null float64
# primary_cleaner.state.floatbank8_d_level      5434 non-null float64
# rougher.input.feed_ag                         5434 non-null float64
# rougher.input.feed_pb                         5434 non-null float64
# rougher.input.feed_rate                       5434 non-null float64
# rougher.input.feed_size                       5434 non-null float64
# rougher.input.feed_sol                        5434 non-null float64
# rougher.input.feed_au                         5434 non-null float64
# rougher.input.floatbank10_sulfate             5434 non-null float64
# rougher.input.floatbank10_xanthate            5434 non-null float64
# rougher.input.floatbank11_sulfate             5434 non-null float64
# rougher.input.floatbank11_xanthate            5434 non-null float64
# rougher.state.floatbank10_a_air               5434 non-null float64
# rougher.state.floatbank10_a_level             5434 non-null float64
# rougher.state.floatbank10_b_air               5434 non-null float64
# rougher.state.floatbank10_b_level             5434 non-null float64
# rougher.state.floatbank10_c_air               5434 non-null float64
# rougher.state.floatbank10_c_level             5434 non-null float64
# rougher.state.floatbank10_d_air               5434 non-null float64
# rougher.state.floatbank10_d_level             5434 non-null float64
# rougher.state.floatbank10_e_air               5434 non-null float64
# rougher.state.floatbank10_e_level             5434 non-null float64
# rougher.state.floatbank10_f_air               5434 non-null float64
# rougher.state.floatbank10_f_level             5434 non-null float64
# secondary_cleaner.state.floatbank2_a_air      5434 non-null float64
# secondary_cleaner.state.floatbank2_a_level    5434 non-null float64
# secondary_cleaner.state.floatbank2_b_air      5434 non-null float64
# secondary_cleaner.state.floatbank2_b_level    5434 non-null float64
# secondary_cleaner.state.floatbank3_a_air      5434 non-null float64
# secondary_cleaner.state.floatbank3_a_level    5434 non-null float64
# secondary_cleaner.state.floatbank3_b_air      5434 non-null float64
# secondary_cleaner.state.floatbank3_b_level    5434 non-null float64
# secondary_cleaner.state.floatbank4_a_air      5434 non-null float64
# secondary_cleaner.state.floatbank4_a_level    5434 non-null float64
# secondary_cleaner.state.floatbank4_b_air      5434 non-null float64
# secondary_cleaner.state.floatbank4_b_level    5434 non-null float64
# secondary_cleaner.state.floatbank5_a_air      5434 non-null float64
# secondary_cleaner.state.floatbank5_a_level    5434 non-null float64
# secondary_cleaner.state.floatbank5_b_air      5434 non-null float64
# secondary_cleaner.state.floatbank5_b_level    5434 non-null float64
# secondary_cleaner.state.floatbank6_a_air      5434 non-null float64
# secondary_cleaner.state.floatbank6_a_level    5434 non-null float64
# dtypes: float64(52), object(1)
# memory usage: 2.2+ MB

# %%
full = full.ffill(axis=0)
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22716 entries, 0 to 22715
# Data columns (total 87 columns):
# date                                                  22716 non-null object
# final.output.concentrate_ag                           22716 non-null float64
# final.output.concentrate_pb                           22716 non-null float64
# final.output.concentrate_sol                          22716 non-null float64
# final.output.concentrate_au                           22716 non-null float64
# final.output.recovery                                 22716 non-null float64
# final.output.tail_ag                                  22716 non-null float64
# final.output.tail_pb                                  22716 non-null float64
# final.output.tail_sol                                 22716 non-null float64
# final.output.tail_au                                  22716 non-null float64
# primary_cleaner.input.sulfate                         22716 non-null float64
# primary_cleaner.input.depressant                      22716 non-null float64
# primary_cleaner.input.feed_size                       22716 non-null float64
# primary_cleaner.input.xanthate                        22716 non-null float64
# primary_cleaner.output.concentrate_ag                 22716 non-null float64
# primary_cleaner.output.concentrate_pb                 22716 non-null float64
# primary_cleaner.output.concentrate_sol                22716 non-null float64
# primary_cleaner.output.concentrate_au                 22716 non-null float64
# primary_cleaner.output.tail_ag                        22716 non-null float64
# primary_cleaner.output.tail_pb                        22716 non-null float64
# primary_cleaner.output.tail_sol                       22716 non-null float64
# primary_cleaner.output.tail_au                        22716 non-null float64
# primary_cleaner.state.floatbank8_a_air                22716 non-null float64
# primary_cleaner.state.floatbank8_a_level              22716 non-null float64
# primary_cleaner.state.floatbank8_b_air                22716 non-null float64
# primary_cleaner.state.floatbank8_b_level              22716 non-null float64
# primary_cleaner.state.floatbank8_c_air                22716 non-null float64
# primary_cleaner.state.floatbank8_c_level              22716 non-null float64
# primary_cleaner.state.floatbank8_d_air                22716 non-null float64
# primary_cleaner.state.floatbank8_d_level              22716 non-null float64
# rougher.calculation.sulfate_to_au_concentrate         22716 non-null float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    22716 non-null float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    22716 non-null float64
# rougher.calculation.au_pb_ratio                       22716 non-null float64
# rougher.input.feed_ag                                 22716 non-null float64
# rougher.input.feed_pb                                 22716 non-null float64
# rougher.input.feed_rate                               22716 non-null float64
# rougher.input.feed_size                               22716 non-null float64
# rougher.input.feed_sol                                22716 non-null float64
# rougher.input.feed_au                                 22716 non-null float64
# rougher.input.floatbank10_sulfate                     22716 non-null float64
# rougher.input.floatbank10_xanthate                    22716 non-null float64
# rougher.input.floatbank11_sulfate                     22716 non-null float64
# rougher.input.floatbank11_xanthate                    22716 non-null float64
# rougher.output.concentrate_ag                         22716 non-null float64
# rougher.output.concentrate_pb                         22716 non-null float64
# rougher.output.concentrate_sol                        22716 non-null float64
# rougher.output.concentrate_au                         22716 non-null float64
# rougher.output.recovery                               22716 non-null float64
# rougher.output.tail_ag                                22716 non-null float64
# rougher.output.tail_pb                                22716 non-null float64
# rougher.output.tail_sol                               22716 non-null float64
# rougher.output.tail_au                                22716 non-null float64
# rougher.state.floatbank10_a_air                       22716 non-null float64
# rougher.state.floatbank10_a_level                     22716 non-null float64
# rougher.state.floatbank10_b_air                       22716 non-null float64
# rougher.state.floatbank10_b_level                     22716 non-null float64
# rougher.state.floatbank10_c_air                       22716 non-null float64
# rougher.state.floatbank10_c_level                     22716 non-null float64
# rougher.state.floatbank10_d_air                       22716 non-null float64
# rougher.state.floatbank10_d_level                     22716 non-null float64
# rougher.state.floatbank10_e_air                       22716 non-null float64
# rougher.state.floatbank10_e_level                     22716 non-null float64
# rougher.state.floatbank10_f_air                       22716 non-null float64
# rougher.state.floatbank10_f_level                     22716 non-null float64
# secondary_cleaner.output.tail_ag                      22716 non-null float64
# secondary_cleaner.output.tail_pb                      22716 non-null float64
# secondary_cleaner.output.tail_sol                     22716 non-null float64
# secondary_cleaner.output.tail_au                      22716 non-null float64
# secondary_cleaner.state.floatbank2_a_air              22716 non-null float64
# secondary_cleaner.state.floatbank2_a_level            22716 non-null float64
# secondary_cleaner.state.floatbank2_b_air              22716 non-null float64
# secondary_cleaner.state.floatbank2_b_level            22716 non-null float64
# secondary_cleaner.state.floatbank3_a_air              22716 non-null float64
# secondary_cleaner.state.floatbank3_a_level            22716 non-null float64
# secondary_cleaner.state.floatbank3_b_air              22716 non-null float64
# secondary_cleaner.state.floatbank3_b_level            22716 non-null float64
# secondary_cleaner.state.floatbank4_a_air              22716 non-null float64
# secondary_cleaner.state.floatbank4_a_level            22716 non-null float64
# secondary_cleaner.state.floatbank4_b_air              22716 non-null float64
# secondary_cleaner.state.floatbank4_b_level            22716 non-null float64
# secondary_cleaner.state.floatbank5_a_air              22716 non-null float64
# secondary_cleaner.state.floatbank5_a_level            22716 non-null float64
# secondary_cleaner.state.floatbank5_b_air              22716 non-null float64
# secondary_cleaner.state.floatbank5_b_level            22716 non-null float64
# secondary_cleaner.state.floatbank6_a_air              22716 non-null float64
# secondary_cleaner.state.floatbank6_a_level            22716 non-null float64
# dtypes: float64(86), object(1)
# memory usage: 15.1+ MB

# %% [markdown]
# В тестовых данных отсутствуют целевые признаки, а именно `rougher.output.recovery` и `final.output.recovery`, поэтому добавим их из исходных данных, чтобы в конце оценить качество модели.

# %%
test['rougher.output.recovery'] = full.query("date in @test.date")['rougher.output.recovery'].values
test['final.output.recovery'] = full.query("date in @test.date")['final.output.recovery'].values

# %% [markdown]
# Так как в тестовой выборке отсустствует ряд признаков, то чтобы создать модель, необходимо учитывать, чтобы количество признаков в тренировочной и тестовой выборках совпадали для корректности предсказаний. Для этого избавимся от части признаков в тренировочной выборке.

# %%
columns_test = list(train.columns[train.columns.isin(test.columns)])
train_new = train[columns_test]
train_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14149 entries, 0 to 16859
# Data columns (total 55 columns):
# date                                          14149 non-null object
# final.output.recovery                         14149 non-null float64
# primary_cleaner.input.sulfate                 14149 non-null float64
# primary_cleaner.input.depressant              14149 non-null float64
# primary_cleaner.input.feed_size               14149 non-null float64
# primary_cleaner.input.xanthate                14149 non-null float64
# primary_cleaner.state.floatbank8_a_air        14149 non-null float64
# primary_cleaner.state.floatbank8_a_level      14149 non-null float64
# primary_cleaner.state.floatbank8_b_air        14149 non-null float64
# primary_cleaner.state.floatbank8_b_level      14149 non-null float64
# primary_cleaner.state.floatbank8_c_air        14149 non-null float64
# primary_cleaner.state.floatbank8_c_level      14149 non-null float64
# primary_cleaner.state.floatbank8_d_air        14149 non-null float64
# primary_cleaner.state.floatbank8_d_level      14149 non-null float64
# rougher.input.feed_ag                         14149 non-null float64
# rougher.input.feed_pb                         14149 non-null float64
# rougher.input.feed_rate                       14149 non-null float64
# rougher.input.feed_size                       14149 non-null float64
# rougher.input.feed_sol                        14149 non-null float64
# rougher.input.feed_au                         14149 non-null float64
# rougher.input.floatbank10_sulfate             14149 non-null float64
# rougher.input.floatbank10_xanthate            14149 non-null float64
# rougher.input.floatbank11_sulfate             14149 non-null float64
# rougher.input.floatbank11_xanthate            14149 non-null float64
# rougher.output.recovery                       14149 non-null float64
# rougher.state.floatbank10_a_air               14149 non-null float64
# rougher.state.floatbank10_a_level             14149 non-null float64
# rougher.state.floatbank10_b_air               14149 non-null float64
# rougher.state.floatbank10_b_level             14149 non-null float64
# rougher.state.floatbank10_c_air               14149 non-null float64
# rougher.state.floatbank10_c_level             14149 non-null float64
# rougher.state.floatbank10_d_air               14149 non-null float64
# rougher.state.floatbank10_d_level             14149 non-null float64
# rougher.state.floatbank10_e_air               14149 non-null float64
# rougher.state.floatbank10_e_level             14149 non-null float64
# rougher.state.floatbank10_f_air               14149 non-null float64
# rougher.state.floatbank10_f_level             14149 non-null float64
# secondary_cleaner.state.floatbank2_a_air      14149 non-null float64
# secondary_cleaner.state.floatbank2_a_level    14149 non-null float64
# secondary_cleaner.state.floatbank2_b_air      14149 non-null float64
# secondary_cleaner.state.floatbank2_b_level    14149 non-null float64
# secondary_cleaner.state.floatbank3_a_air      14149 non-null float64
# secondary_cleaner.state.floatbank3_a_level    14149 non-null float64
# secondary_cleaner.state.floatbank3_b_air      14149 non-null float64
# secondary_cleaner.state.floatbank3_b_level    14149 non-null float64
# secondary_cleaner.state.floatbank4_a_air      14149 non-null float64
# secondary_cleaner.state.floatbank4_a_level    14149 non-null float64
# secondary_cleaner.state.floatbank4_b_air      14149 non-null float64
# secondary_cleaner.state.floatbank4_b_level    14149 non-null float64
# secondary_cleaner.state.floatbank5_a_air      14149 non-null float64
# secondary_cleaner.state.floatbank5_a_level    14149 non-null float64
# secondary_cleaner.state.floatbank5_b_air      14149 non-null float64
# secondary_cleaner.state.floatbank5_b_level    14149 non-null float64
# secondary_cleaner.state.floatbank6_a_air      14149 non-null float64
# secondary_cleaner.state.floatbank6_a_level    14149 non-null float64
# dtypes: float64(54), object(1)
# memory usage: 6.0+ MB

# %% [markdown]
# ### Вывод
#
# Данные представленны в трех выборках: тренировочной, тестовой и исходной(полной). Был произведен расчет средней абсолютной ошибки МАЕ и она оказалась близка к 0, что говорит о том, что представленные данные полностью соответствуют теоретическим расчетамы эффективности обогащения золотосодержащей руды. Так же была произведена предобработка данных, а именно были заполнены пропуски, в тестовую выборку были добавлены целевые признаки и в тренировочной выборке оставили только те признаки, которые есть в тестовой.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Исследование распределений концентрации металлов

# %% [markdown]
# Посмотрим как меняется концентрация металов на различных этапах очистки.

# %%
def plots_conc(df):
    for elem in ['ag', 'pb', 'sol', 'au']:
        ax = df.plot(
            y='final.output.concentrate_'+elem, kind='hist', histtype='step', bins=100,
            grid=True, figsize=(12, 9), label='Финал')
        df.plot(
            y='primary_cleaner.output.concentrate_'+elem, kind='hist', histtype='step', bins=100,
            grid=True, ax=ax, label='Первичная очистка')
        df.plot(
            y='rougher.output.concentrate_'+elem, kind='hist', histtype='step', bins=100,
            grid=True, ax=ax, color='red', label='Флотация')
        plt.title('Концентрация ' + elem)
        plt.show()

# %%
plots_conc(full)

# %% [markdown]
# По гистограммам можно увидеть, что концентрации различных металлов при прохождении через этапы очистки руды ведут себя по разному.
#
#     - Концентрация Ag имеет явную нисходящую тенденцию от этапа флотации до финального этапа
#     - Концентрация Pb остается почти не изменной
#     - Концентрация Sol в свою очередь резко снижается на этапе первичной очистки и после остается почти неизменной
#     - Концентрация же Золота повышается от этапа к этапу.
#
# Кроме того для всех металлов и на всех этапах есть множественные выбросы в районе концентрации равной нулю. Это может быть связано с ошибкой в расчетах приборов при вычислении концентрации продукта.
#
# В остальном же распределения всех металлов по всем этапам нормальное, что говорит о корректности имеющихся данных.

# %% [markdown]
# ### Сравнение распределений размеров гранул сырья
#
# Сравним распределения размеров гранул сырья на обучающей и тестовой выборках.

# %%
ax = train_new.plot(y='rougher.input.feed_size', kind='hist',
                    histtype='step', density=True, bins=100,
                    grid=True, figsize=(12, 6), label='train')
test.plot(y='rougher.input.feed_size', kind='hist', histtype='step',
          density=True, bins=100, grid=True, ax=ax,
          label='test', color='red')
plt.title('Размер гранул сырья')
plt.xlim([0, 150])
plt.show()

# %% [markdown]
# Распределения размеров гранул сырья на тестовой и тренировочных выборках нормальные и почти не отличаются друг от друга.

# %% [markdown]
# ### Исследование суммарной концентрации металлов

# %%
ag = '.output.concentrate_ag'
pb = '.output.concentrate_pb'
sol = '.output.concentrate_sol'
au = '.output.concentrate_au'
conc_sum = pd.DataFrame(columns=['rougher', 'primary_cleaner', 'final'])
for n in ['rougher', 'primary_cleaner', 'final']:
    conc_sum[n] = full[n + ag] + full[n + pb] + full[n + sol] + full[n + au]

ax = conc_sum.plot(y='final', kind='hist', histtype='step', bins=100, grid=True, figsize=(12, 9), label='Финал')
conc_sum.plot(y='primary_cleaner', kind='hist', histtype='step', bins=100, grid=True, ax=ax, label='Первичная очистка')
conc_sum.plot(y='rougher', kind='hist', histtype='step', bins=100, grid=True, ax=ax, color='red', label='Флотация')
plt.title('Суммарная концентрация')
plt.show()

# %% [markdown]
# Распределения суммарных концентраций по этапам имеют нормальный характер. Как и в гистограммах концентраций присутствуют выбросы в районе нуля, что может быть связано с ошибкой приборов и/или расчетов. Удалим выбросы.

# %%
conc_sum_new = conc_sum.query('(final > 0.5) and (primary_cleaner > 0.5) and (rougher > 0.5)')
ax = conc_sum_new.plot(y='final', kind='hist', histtype='step', bins=100, grid=True, figsize=(12, 9), label='Финал')
conc_sum_new.plot(y='primary_cleaner', kind='hist', histtype='step', bins=100, grid=True, ax=ax, label='Первичная очистка')
conc_sum_new.plot(y='rougher', kind='hist', histtype='step', bins=100, grid=True, ax=ax, color='red', label='Флотация')
plt.title('Суммарная концентрация')
plt.show()

# %% [markdown]
# Удаление выбросов из тренировочной и тестовой выборок. Удалять будем по времени измерения.

# %%
test.shape
# Out:
# (5434, 55)

# %%
index_del = conc_sum.query('(final > 0.5) and (primary_cleaner > 0.5) and (rougher > 0.5)').index
date_del = full.loc[full.index.isin(index_del)]['date']
train_new = train_new.loc[train_new['date'].isin(date_del)]
test = test.loc[test['date'].isin(date_del)]
test.shape
# Out:
# (5232, 55)

# %% [markdown]
# Исследуем имеющиеся признаки на мультиколлинеарность и отсеим те, у который корреляции будут больше 85%.

# %%
train_new.corr()
# Out:
#                                             final.output.recovery  \
# final.output.recovery                                    1.000000
# primary_cleaner.input.sulfate                            0.387696
# primary_cleaner.input.depressant                         0.153230
# primary_cleaner.input.feed_size                          0.063632
# primary_cleaner.input.xanthate                           0.228686
# primary_cleaner.state.floatbank8_a_air                   0.164572
# primary_cleaner.state.floatbank8_a_level                 0.048617
# primary_cleaner.state.floatbank8_b_air                   0.182135
# primary_cleaner.state.floatbank8_b_level                 0.041923
# primary_cleaner.state.floatbank8_c_air                   0.170274
# primary_cleaner.state.floatbank8_c_level                 0.046174
# primary_cleaner.state.floatbank8_d_air                   0.072097
# primary_cleaner.state.floatbank8_d_level                -0.037883
# rougher.input.feed_ag                                    0.343843
# rougher.input.feed_pb                                    0.220068
# rougher.input.feed_rate                                  0.166394
# rougher.input.feed_size                                  0.048492
# rougher.input.feed_sol                                   0.281351
# rougher.input.feed_au                                    0.336689
# rougher.input.floatbank10_sulfate                       -0.020782
# rougher.input.floatbank10_xanthate                       0.340180
# rougher.input.floatbank11_sulfate                        0.002680
# rougher.input.floatbank11_xanthate                       0.313491
# rougher.output.recovery                                  0.610362
# rougher.state.floatbank10_a_air                          0.252233
# rougher.state.floatbank10_a_level                        0.101910
# rougher.state.floatbank10_b_air                         -0.156328
# rougher.state.floatbank10_b_level                       -0.085970
# rougher.state.floatbank10_c_air                         -0.197208
# rougher.state.floatbank10_c_level                       -0.096435
# rougher.state.floatbank10_d_air                         -0.188918
# rougher.state.floatbank10_d_level                       -0.095908
# rougher.state.floatbank10_e_air                         -0.138313
# rougher.state.floatbank10_e_level                       -0.097386
# rougher.state.floatbank10_f_air                         -0.098262
# rougher.state.floatbank10_f_level                       -0.095471
# secondary_cleaner.state.floatbank2_a_air                 0.157861
# secondary_cleaner.state.floatbank2_a_level              -0.012117
# secondary_cleaner.state.floatbank2_b_air                 0.142492
# secondary_cleaner.state.floatbank2_b_level              -0.018907
# secondary_cleaner.state.floatbank3_a_air                 0.216843
# secondary_cleaner.state.floatbank3_a_level               0.030565
# secondary_cleaner.state.floatbank3_b_air                 0.049629
# secondary_cleaner.state.floatbank3_b_level              -0.000084
# secondary_cleaner.state.floatbank4_a_air                 0.232027
# secondary_cleaner.state.floatbank4_a_level               0.056981
# secondary_cleaner.state.floatbank4_b_air                 0.192716
# secondary_cleaner.state.floatbank4_b_level              -0.109026
# secondary_cleaner.state.floatbank5_a_air                 0.116552
# secondary_cleaner.state.floatbank5_a_level               0.029891
# secondary_cleaner.state.floatbank5_b_air                 0.085689
# secondary_cleaner.state.floatbank5_b_level               0.047039
# secondary_cleaner.state.floatbank6_a_air                -0.015535
# secondary_cleaner.state.floatbank6_a_level              -0.051609
#
#                                             primary_cleaner.input.sulfate  \
# final.output.recovery                                            0.387696
# primary_cleaner.input.sulfate                                    1.000000
# primary_cleaner.input.depressant                                 0.482760
# primary_cleaner.input.feed_size                                  0.159131
# primary_cleaner.input.xanthate                                   0.265594
# primary_cleaner.state.floatbank8_a_air                           0.030800
# primary_cleaner.state.floatbank8_a_level                        -0.046685
# primary_cleaner.state.floatbank8_b_air                           0.054223
# primary_cleaner.state.floatbank8_b_level                        -0.042548
# primary_cleaner.state.floatbank8_c_air                           0.051433
# primary_cleaner.state.floatbank8_c_level                        -0.038071
# primary_cleaner.state.floatbank8_d_air                           0.116606
# primary_cleaner.state.floatbank8_d_level                        -0.038225
# rougher.input.feed_ag                                            0.549755
# rougher.input.feed_pb                                            0.570272
# rougher.input.feed_rate                                          0.300579
# rougher.input.feed_size                                         -0.084517
# rougher.input.feed_sol                                           0.378502
# rougher.input.feed_au                                            0.614403
# rougher.input.floatbank10_sulfate                                0.392701
# rougher.input.floatbank10_xanthate                               0.367736
# rougher.input.floatbank11_sulfate                                0.504371
# rougher.input.floatbank11_xanthate                               0.404837
# rougher.output.recovery                                          0.430022
# rougher.state.floatbank10_a_air                                  0.206087
# rougher.state.floatbank10_a_level                                0.084398
# rougher.state.floatbank10_b_air                                 -0.236930
# rougher.state.floatbank10_b_level                               -0.234320
# rougher.state.floatbank10_c_air                                 -0.264936
# rougher.state.floatbank10_c_level                               -0.236550
# rougher.state.floatbank10_d_air                                 -0.301797
# rougher.state.floatbank10_d_level                               -0.235158
# rougher.state.floatbank10_e_air                                 -0.271892
# rougher.state.floatbank10_e_level                               -0.241142
# rougher.state.floatbank10_f_air                                 -0.248188
# rougher.state.floatbank10_f_level                               -0.241486
# secondary_cleaner.state.floatbank2_a_air                         0.127040
# secondary_cleaner.state.floatbank2_a_level                       0.103207
# secondary_cleaner.state.floatbank2_b_air                         0.130491
# secondary_cleaner.state.floatbank2_b_level                       0.121778
# secondary_cleaner.state.floatbank3_a_air                         0.082056
# secondary_cleaner.state.floatbank3_a_level                      -0.024298
# secondary_cleaner.state.floatbank3_b_air                        -0.000424
# secondary_cleaner.state.floatbank3_b_level                      -0.054398
# secondary_cleaner.state.floatbank4_a_air                         0.085533
# secondary_cleaner.state.floatbank4_a_level                       0.023842
# secondary_cleaner.state.floatbank4_b_air                         0.106062
# secondary_cleaner.state.floatbank4_b_level                      -0.061111
# secondary_cleaner.state.floatbank5_a_air                        -0.004881
# secondary_cleaner.state.floatbank5_a_level                      -0.040553
# secondary_cleaner.state.floatbank5_b_air                         0.004463
# secondary_cleaner.state.floatbank5_b_level                      -0.035560
# secondary_cleaner.state.floatbank6_a_air                        -0.109835
# secondary_cleaner.state.floatbank6_a_level                      -0.153506
#
#                                             primary_cleaner.input.depressant  \
# final.output.recovery                                               0.153230
# primary_cleaner.input.sulfate                                       0.482760
# primary_cleaner.input.depressant                                    1.000000
# primary_cleaner.input.feed_size                                     0.169035
# primary_cleaner.input.xanthate                                      0.276970
# primary_cleaner.state.floatbank8_a_air                             -0.149763
# primary_cleaner.state.floatbank8_a_level                            0.121206
# primary_cleaner.state.floatbank8_b_air                             -0.110240
# primary_cleaner.state.floatbank8_b_level                            0.137093
# primary_cleaner.state.floatbank8_c_air                             -0.123227
# primary_cleaner.state.floatbank8_c_level                            0.139157
# primary_cleaner.state.floatbank8_d_air                             -0.094114
# primary_cleaner.state.floatbank8_d_level                            0.057142
# rougher.input.feed_ag                                               0.478826
# rougher.input.feed_pb                                               0.278330
# rougher.input.feed_rate                                             0.150443
# rougher.input.feed_size                                            -0.082547
# rougher.input.feed_sol                                              0.082914
# rougher.input.feed_au                                               0.420460
# rougher.input.floatbank10_sulfate                                   0.133277
# rougher.input.floatbank10_xanthate                                  0.369459
# rougher.input.floatbank11_sulfate                                   0.249785
# rougher.input.floatbank11_xanthate                                  0.417767
# rougher.output.recovery                                             0.121816
# rougher.state.floatbank10_a_air                                    -0.036154
# rougher.state.floatbank10_a_level                                  -0.270250
# rougher.state.floatbank10_b_air                                    -0.116750
# rougher.state.floatbank10_b_level                                  -0.328159
# rougher.state.floatbank10_c_air                                    -0.148714
# rougher.state.floatbank10_c_level                                  -0.326042
# rougher.state.floatbank10_d_air                                    -0.134029
# rougher.state.floatbank10_d_level                                  -0.325993
# rougher.state.floatbank10_e_air                                    -0.039539
# rougher.state.floatbank10_e_level                                  -0.332577
# rougher.state.floatbank10_f_air                                    -0.068300
# rougher.state.floatbank10_f_level                                  -0.335749
# secondary_cleaner.state.floatbank2_a_air                           -0.056276
# secondary_cleaner.state.floatbank2_a_level                          0.189090
# secondary_cleaner.state.floatbank2_b_air                            0.079381
# secondary_cleaner.state.floatbank2_b_level                          0.177592
# secondary_cleaner.state.floatbank3_a_air                           -0.171452
# secondary_cleaner.state.floatbank3_a_level                         -0.083082
# secondary_cleaner.state.floatbank3_b_air                            0.019971
# secondary_cleaner.state.floatbank3_b_level                          0.006750
# secondary_cleaner.state.floatbank4_a_air                           -0.235346
# secondary_cleaner.state.floatbank4_a_level                         -0.165530
# secondary_cleaner.state.floatbank4_b_air                           -0.133068
# secondary_cleaner.state.floatbank4_b_level                         -0.288016
# secondary_cleaner.state.floatbank5_a_air                           -0.262042
# secondary_cleaner.state.floatbank5_a_level                         -0.164564
# secondary_cleaner.state.floatbank5_b_air                           -0.218046
# secondary_cleaner.state.floatbank5_b_level                         -0.156878
# secondary_cleaner.state.floatbank6_a_air                           -0.167633
# secondary_cleaner.state.floatbank6_a_level                         -0.131402
#
#                                             primary_cleaner.input.feed_size  \
# final.output.recovery                                              0.063632
# primary_cleaner.input.sulfate                                      0.159131
# primary_cleaner.input.depressant                                   0.169035
# primary_cleaner.input.feed_size                                    1.000000
# primary_cleaner.input.xanthate                                    -0.004874
# primary_cleaner.state.floatbank8_a_air                            -0.128819
# primary_cleaner.state.floatbank8_a_level                           0.080259
# primary_cleaner.state.floatbank8_b_air                            -0.128196
# primary_cleaner.state.floatbank8_b_level                           0.083347
# primary_cleaner.state.floatbank8_c_air                            -0.153819
# primary_cleaner.state.floatbank8_c_level                           0.080875
# primary_cleaner.state.floatbank8_d_air                            -0.196942
# primary_cleaner.state.floatbank8_d_level                           0.074864
# rougher.input.feed_ag                                              0.111101
# rougher.input.feed_pb                                             -0.098791
# rougher.input.feed_rate                                            0.084213
# rougher.input.feed_size                                           -0.145366
# rougher.input.feed_sol                                             0.067227
# rougher.input.feed_au                                              0.122519
# rougher.input.floatbank10_sulfate                                  0.095251
# rougher.input.floatbank10_xanthate                                 0.011879
# rougher.input.floatbank11_sulfate                                  0.154513
# rougher.input.floatbank11_xanthate                                 0.049695
# rougher.output.recovery                                           -0.056342
# rougher.state.floatbank10_a_air                                   -0.219273
# rougher.state.floatbank10_a_level                                 -0.356836
# rougher.state.floatbank10_b_air                                    0.182026
# rougher.state.floatbank10_b_level                                  0.073502
# rougher.state.floatbank10_c_air                                    0.191734
# rougher.state.floatbank10_c_level                                  0.064031
# rougher.state.floatbank10_d_air                                    0.195607
# rougher.state.floatbank10_d_level                                  0.061212
# rougher.state.floatbank10_e_air                                    0.146804
# rougher.state.floatbank10_e_level                                  0.059438
# rougher.state.floatbank10_f_air                                    0.134828
# rougher.state.floatbank10_f_level                                  0.059173
# secondary_cleaner.state.floatbank2_a_air                          -0.175299
# secondary_cleaner.state.floatbank2_a_level                         0.108357
# secondary_cleaner.state.floatbank2_b_air                          -0.135734
# secondary_cleaner.state.floatbank2_b_level                         0.086999
# secondary_cleaner.state.floatbank3_a_air                          -0.156868
# secondary_cleaner.state.floatbank3_a_level                         0.095296
# secondary_cleaner.state.floatbank3_b_air                           0.013619
# secondary_cleaner.state.floatbank3_b_level                         0.134495
# secondary_cleaner.state.floatbank4_a_air                          -0.329768
# secondary_cleaner.state.floatbank4_a_level                         0.111123
# secondary_cleaner.state.floatbank4_b_air                          -0.252157
# secondary_cleaner.state.floatbank4_b_level                         0.022349
# secondary_cleaner.state.floatbank5_a_air                          -0.227850
# secondary_cleaner.state.floatbank5_a_level                         0.125880
# secondary_cleaner.state.floatbank5_b_air                          -0.212746
# secondary_cleaner.state.floatbank5_b_level                         0.128223
# secondary_cleaner.state.floatbank6_a_air                           0.150701
# secondary_cleaner.state.floatbank6_a_level                         0.063868
#
#                                             primary_cleaner.input.xanthate  \
# final.output.recovery                                             0.228686
# primary_cleaner.input.sulfate                                     0.265594
# primary_cleaner.input.depressant                                  0.276970
# primary_cleaner.input.feed_size                                  -0.004874
# primary_cleaner.input.xanthate                                    1.000000
# primary_cleaner.state.floatbank8_a_air                            0.067563
# primary_cleaner.state.floatbank8_a_level                          0.024732
# primary_cleaner.state.floatbank8_b_air                            0.097669
# primary_cleaner.state.floatbank8_b_level                          0.021219
# primary_cleaner.state.floatbank8_c_air                            0.061976
# primary_cleaner.state.floatbank8_c_level                          0.018879
# primary_cleaner.state.floatbank8_d_air                            0.113731
# primary_cleaner.state.floatbank8_d_level                         -0.036498
# rougher.input.feed_ag                                             0.253933
# rougher.input.feed_pb                                            -0.021709
# rougher.input.feed_rate                                           0.281608
# rougher.input.feed_size                                           0.059315
# rougher.input.feed_sol                                            0.178892
# rougher.input.feed_au                                             0.146550
# rougher.input.floatbank10_sulfate                                -0.136281
# rougher.input.floatbank10_xanthate                                0.390670
# rougher.input.floatbank11_sulfate                                -0.038804
# rougher.input.floatbank11_xanthate                                0.399218
# rougher.output.recovery                                           0.192592
# rougher.state.floatbank10_a_air                                   0.146321
# rougher.state.floatbank10_a_level                                -0.063800
# rougher.state.floatbank10_b_air                                  -0.262535
# rougher.state.floatbank10_b_level                                -0.316232
# rougher.state.floatbank10_c_air                                  -0.292728
# rougher.state.floatbank10_c_level                                -0.325607
# rougher.state.floatbank10_d_air                                  -0.241691
# rougher.state.floatbank10_d_level                                -0.323557
# rougher.state.floatbank10_e_air                                  -0.109691
# rougher.state.floatbank10_e_level                                -0.319834
# rougher.state.floatbank10_f_air                                  -0.109538
# rougher.state.floatbank10_f_level                                -0.314216
# secondary_cleaner.state.floatbank2_a_air                         -0.087231
# secondary_cleaner.state.floatbank2_a_level                       -0.093226
# secondary_cleaner.state.floatbank2_b_air                         -0.015493
# secondary_cleaner.state.floatbank2_b_level                       -0.086657
# secondary_cleaner.state.floatbank3_a_air                          0.033163
# secondary_cleaner.state.floatbank3_a_level                       -0.252680
# secondary_cleaner.state.floatbank3_b_air                         -0.075510
# secondary_cleaner.state.floatbank3_b_level                       -0.113703
# secondary_cleaner.state.floatbank4_a_air                          0.033455
# secondary_cleaner.state.floatbank4_a_level                       -0.215548
# secondary_cleaner.state.floatbank4_b_air                          0.009160
# secondary_cleaner.state.floatbank4_b_level                       -0.331534
# secondary_cleaner.state.floatbank5_a_air                         -0.082264
# secondary_cleaner.state.floatbank5_a_level                       -0.205010
# secondary_cleaner.state.floatbank5_b_air                         -0.096181
# secondary_cleaner.state.floatbank5_b_level                       -0.203699
# secondary_cleaner.state.floatbank6_a_air                         -0.222071
# secondary_cleaner.state.floatbank6_a_level                       -0.080971
#
#                                             primary_cleaner.state.floatbank8_a_air  \
# final.output.recovery                                                     0.164572
# primary_cleaner.input.sulfate                                             0.030800
# primary_cleaner.input.depressant                                         -0.149763
# primary_cleaner.input.feed_size                                          -0.128819
# primary_cleaner.input.xanthate                                            0.067563
# primary_cleaner.state.floatbank8_a_air                                    1.000000
# primary_cleaner.state.floatbank8_a_level                                  0.159626
# primary_cleaner.state.floatbank8_b_air                                    0.944750
# primary_cleaner.state.floatbank8_b_level                                  0.169392
# primary_cleaner.state.floatbank8_c_air                                    0.934217
# primary_cleaner.state.floatbank8_c_level                                  0.168945
# primary_cleaner.state.floatbank8_d_air                                    0.313279
# primary_cleaner.state.floatbank8_d_level                                  0.070526
# rougher.input.feed_ag                                                     0.173299
# rougher.input.feed_pb                                                     0.022835
# rougher.input.feed_rate                                                  -0.102692
# rougher.input.feed_size                                                   0.083161
# rougher.input.feed_sol                                                    0.049954
# rougher.input.feed_au                                                     0.096713
# rougher.input.floatbank10_sulfate                                        -0.059307
# rougher.input.floatbank10_xanthate                                       -0.011365
# rougher.input.floatbank11_sulfate                                        -0.121673
# rougher.input.floatbank11_xanthate                                       -0.058592
# rougher.output.recovery                                                   0.205544
# rougher.state.floatbank10_a_air                                           0.382606
# rougher.state.floatbank10_a_level                                         0.239447
# rougher.state.floatbank10_b_air                                           0.197976
# rougher.state.floatbank10_b_level                                         0.360404
# rougher.state.floatbank10_c_air                                           0.158266
# rougher.state.floatbank10_c_level                                         0.353412
# rougher.state.floatbank10_d_air                                           0.170383
# rougher.state.floatbank10_d_level                                         0.352593
# rougher.state.floatbank10_e_air                                           0.217327
# rougher.state.floatbank10_e_level                                         0.361303
# rougher.state.floatbank10_f_air                                           0.234464
# rougher.state.floatbank10_f_level                                         0.357982
# secondary_cleaner.state.floatbank2_a_air                                  0.262104
# secondary_cleaner.state.floatbank2_a_level                               -0.056140
# secondary_cleaner.state.floatbank2_b_air                                  0.246182
# secondary_cleaner.state.floatbank2_b_level                               -0.033463
# secondary_cleaner.state.floatbank3_a_air                                  0.459886
# secondary_cleaner.state.floatbank3_a_level                                0.305560
# secondary_cleaner.state.floatbank3_b_air                                  0.323189
# secondary_cleaner.state.floatbank3_b_level                                0.047242
# secondary_cleaner.state.floatbank4_a_air                                  0.542972
# secondary_cleaner.state.floatbank4_a_level                                0.331114
# secondary_cleaner.state.floatbank4_b_air                                  0.514967
# secondary_cleaner.state.floatbank4_b_level                                0.219727
# secondary_cleaner.state.floatbank5_a_air                                  0.547463
# secondary_cleaner.state.floatbank5_a_level                                0.259488
# secondary_cleaner.state.floatbank5_b_air                                  0.493946
# secondary_cleaner.state.floatbank5_b_level                                0.251556
# secondary_cleaner.state.floatbank6_a_air                                  0.305451
# secondary_cleaner.state.floatbank6_a_level                                0.054051
#
#                                             primary_cleaner.state.floatbank8_a_level  \
# final.output.recovery                                                       0.048617
# primary_cleaner.input.sulfate                                              -0.046685
# primary_cleaner.input.depressant                                            0.121206
# primary_cleaner.input.feed_size                                             0.080259
# primary_cleaner.input.xanthate                                              0.024732
# primary_cleaner.state.floatbank8_a_air                                      0.159626
# primary_cleaner.state.floatbank8_a_level                                    1.000000
# primary_cleaner.state.floatbank8_b_air                                      0.119592
# primary_cleaner.state.floatbank8_b_level                                    0.977623
# primary_cleaner.state.floatbank8_c_air                                      0.150804
# primary_cleaner.state.floatbank8_c_level                                    0.963276
# primary_cleaner.state.floatbank8_d_air                                     -0.421908
# primary_cleaner.state.floatbank8_d_level                                    0.723695
# rougher.input.feed_ag                                                      -0.004755
# rougher.input.feed_pb                                                      -0.055033
# rougher.input.feed_rate                                                     0.043140
# rougher.input.feed_size                                                    -0.037824
# rougher.input.feed_sol                                                     -0.135689
# rougher.input.feed_au                                                      -0.068717
# rougher.input.floatbank10_sulfate                                          -0.162807
# rougher.input.floatbank10_xanthate                                          0.216811
# rougher.input.floatbank11_sulfate                                          -0.107550
# rougher.input.floatbank11_xanthate                                          0.205463
# rougher.output.recovery                                                     0.011316
# rougher.state.floatbank10_a_air                                            -0.048731
# rougher.state.floatbank10_a_level                                          -0.198137
# rougher.state.floatbank10_b_air                                             0.207407
# rougher.state.floatbank10_b_level                                          -0.083666
# rougher.state.floatbank10_c_air                                             0.169721
# rougher.state.floatbank10_c_level                                          -0.106343
# rougher.state.floatbank10_d_air                                             0.251747
# rougher.state.floatbank10_d_level                                          -0.109847
# rougher.state.floatbank10_e_air                                             0.278439
# rougher.state.floatbank10_e_level                                          -0.099001
# rougher.state.floatbank10_f_air                                             0.317004
# rougher.state.floatbank10_f_level                                          -0.106783
# secondary_cleaner.state.floatbank2_a_air                                    0.153002
# secondary_cleaner.state.floatbank2_a_level                                  0.190675
# secondary_cleaner.state.floatbank2_b_air                                    0.224813
# secondary_cleaner.state.floatbank2_b_level                                  0.167565
# secondary_cleaner.state.floatbank3_a_air                                    0.003941
# secondary_cleaner.state.floatbank3_a_level                                  0.071897
# secondary_cleaner.state.floatbank3_b_air                                    0.224525
# secondary_cleaner.state.floatbank3_b_level                                  0.170110
# secondary_cleaner.state.floatbank4_a_air                                   -0.052862
# secondary_cleaner.state.floatbank4_a_level                                  0.050930
# secondary_cleaner.state.floatbank4_b_air                                    0.085583
# secondary_cleaner.state.floatbank4_b_level                                 -0.044711
# secondary_cleaner.state.floatbank5_a_air                                    0.001763
# secondary_cleaner.state.floatbank5_a_level                                  0.104934
# secondary_cleaner.state.floatbank5_b_air                                    0.063462
# secondary_cleaner.state.floatbank5_b_level                                  0.081126
# secondary_cleaner.state.floatbank6_a_air                                    0.171686
# secondary_cleaner.state.floatbank6_a_level                                  0.188921
#
#                                             primary_cleaner.state.floatbank8_b_air  \
# final.output.recovery                                                     0.182135
# primary_cleaner.input.sulfate                                             0.054223
# primary_cleaner.input.depressant                                         -0.110240
# primary_cleaner.input.feed_size                                          -0.128196
# primary_cleaner.input.xanthate                                            0.097669
# primary_cleaner.state.floatbank8_a_air                                    0.944750
# primary_cleaner.state.floatbank8_a_level                                  0.119592
# primary_cleaner.state.floatbank8_b_air                                    1.000000
# primary_cleaner.state.floatbank8_b_level                                  0.144668
# primary_cleaner.state.floatbank8_c_air                                    0.940144
# primary_cleaner.state.floatbank8_c_level                                  0.144923
# primary_cleaner.state.floatbank8_d_air                                    0.321389
# primary_cleaner.state.floatbank8_d_level                                  0.043217
# rougher.input.feed_ag                                                     0.209135
# rougher.input.feed_pb                                                     0.034615
# rougher.input.feed_rate                                                  -0.101995
# rougher.input.feed_size                                                   0.050701
# rougher.input.feed_sol                                                    0.043274
# rougher.input.feed_au                                                     0.130961
# rougher.input.floatbank10_sulfate                                        -0.081060
# rougher.input.floatbank10_xanthate                                        0.024385
# rougher.input.floatbank11_sulfate                                        -0.121829
# rougher.input.floatbank11_xanthate                                       -0.011878
# rougher.output.recovery                                                   0.230730
# rougher.state.floatbank10_a_air                                           0.426110
# rougher.state.floatbank10_a_level                                         0.231980
# rougher.state.floatbank10_b_air                                           0.187512
# rougher.state.floatbank10_b_level                                         0.337273
# rougher.state.floatbank10_c_air                                           0.140003
# rougher.state.floatbank10_c_level                                         0.325633
# rougher.state.floatbank10_d_air                                           0.150921
# rougher.state.floatbank10_d_level                                         0.324225
# rougher.state.floatbank10_e_air                                           0.205307
# rougher.state.floatbank10_e_level                                         0.333589
# rougher.state.floatbank10_f_air                                           0.221263
# rougher.state.floatbank10_f_level                                         0.333665
# secondary_cleaner.state.floatbank2_a_air                                  0.206380
# secondary_cleaner.state.floatbank2_a_level                               -0.081699
# secondary_cleaner.state.floatbank2_b_air                                  0.211242
# secondary_cleaner.state.floatbank2_b_level                               -0.052990
# secondary_cleaner.state.floatbank3_a_air                                  0.439414
# secondary_cleaner.state.floatbank3_a_level                                0.316631
# secondary_cleaner.state.floatbank3_b_air                                  0.294382
# secondary_cleaner.state.floatbank3_b_level                                0.046357
# secondary_cleaner.state.floatbank4_a_air                                  0.524584
# secondary_cleaner.state.floatbank4_a_level                                0.344053
# secondary_cleaner.state.floatbank4_b_air                                  0.512096
# secondary_cleaner.state.floatbank4_b_level                                0.194622
# secondary_cleaner.state.floatbank5_a_air                                  0.547338
# secondary_cleaner.state.floatbank5_a_level                                0.266681
# secondary_cleaner.state.floatbank5_b_air                                  0.480013
# secondary_cleaner.state.floatbank5_b_level                                0.259320
# secondary_cleaner.state.floatbank6_a_air                                  0.306476
# secondary_cleaner.state.floatbank6_a_level                                0.032635
#
#                                             primary_cleaner.state.floatbank8_b_level  \
# final.output.recovery                                                       0.041923
# primary_cleaner.input.sulfate                                              -0.042548
# primary_cleaner.input.depressant                                            0.137093
# primary_cleaner.input.feed_size                                             0.083347
# primary_cleaner.input.xanthate                                              0.021219
# primary_cleaner.state.floatbank8_a_air                                      0.169392
# primary_cleaner.state.floatbank8_a_level                                    0.977623
# primary_cleaner.state.floatbank8_b_air                                      0.144668
# primary_cleaner.state.floatbank8_b_level                                    1.000000
# primary_cleaner.state.floatbank8_c_air                                      0.161190
# primary_cleaner.state.floatbank8_c_level                                    0.967360
# primary_cleaner.state.floatbank8_d_air                                     -0.440892
# primary_cleaner.state.floatbank8_d_level                                    0.723190
# rougher.input.feed_ag                                                       0.011922
# rougher.input.feed_pb                                                      -0.056496
# rougher.input.feed_rate                                                     0.035985
# rougher.input.feed_size                                                    -0.046544
# rougher.input.feed_sol                                                     -0.152937
# rougher.input.feed_au                                                      -0.055698
# rougher.input.floatbank10_sulfate                                          -0.153533
# rougher.input.floatbank10_xanthate                                          0.220694
# rougher.input.floatbank11_sulfate                                          -0.100263
# rougher.input.floatbank11_xanthate                                          0.207930
# rougher.output.recovery                                                     0.006600
# rougher.state.floatbank10_a_air                                            -0.057558
# rougher.state.floatbank10_a_level                                          -0.216106
# rougher.state.floatbank10_b_air                                             0.224149
# rougher.state.floatbank10_b_level                                          -0.074786
# rougher.state.floatbank10_c_air                                             0.182864
# rougher.state.floatbank10_c_level                                          -0.098320
# rougher.state.floatbank10_d_air                                             0.268412
# rougher.state.floatbank10_d_level                                          -0.102287
# rougher.state.floatbank10_e_air                                             0.293447
# rougher.state.floatbank10_e_level                                          -0.090677
# rougher.state.floatbank10_f_air                                             0.330446
# rougher.state.floatbank10_f_level                                          -0.098791
# secondary_cleaner.state.floatbank2_a_air                                    0.138489
# secondary_cleaner.state.floatbank2_a_level                                  0.197333
# secondary_cleaner.state.floatbank2_b_air                                    0.218287
# secondary_cleaner.state.floatbank2_b_level                                  0.173103
# secondary_cleaner.state.floatbank3_a_air                                   -0.015408
# secondary_cleaner.state.floatbank3_a_level                                  0.082969
# secondary_cleaner.state.floatbank3_b_air                                    0.215755
# secondary_cleaner.state.floatbank3_b_level                                  0.184049
# secondary_cleaner.state.floatbank4_a_air                                   -0.077470
# secondary_cleaner.state.floatbank4_a_level                                  0.062270
# secondary_cleaner.state.floatbank4_b_air                                    0.071120
# secondary_cleaner.state.floatbank4_b_level                                 -0.034587
# secondary_cleaner.state.floatbank5_a_air                                   -0.018430
# secondary_cleaner.state.floatbank5_a_level                                  0.118909
# secondary_cleaner.state.floatbank5_b_air                                    0.040806
# secondary_cleaner.state.floatbank5_b_level                                  0.094091
# secondary_cleaner.state.floatbank6_a_air                                    0.166693
# secondary_cleaner.state.floatbank6_a_level                                  0.194177
#
#                                             primary_cleaner.state.floatbank8_c_air  \
# final.output.recovery                                                     0.170274
# primary_cleaner.input.sulfate                                             0.051433
# primary_cleaner.input.depressant                                         -0.123227
# primary_cleaner.input.feed_size                                          -0.153819
# primary_cleaner.input.xanthate                                            0.061976
# primary_cleaner.state.floatbank8_a_air                                    0.934217
# primary_cleaner.state.floatbank8_a_level                                  0.150804
# primary_cleaner.state.floatbank8_b_air                                    0.940144
# primary_cleaner.state.floatbank8_b_level                                  0.161190
# primary_cleaner.state.floatbank8_c_air                                    1.000000
# primary_cleaner.state.floatbank8_c_level                                  0.162542
# primary_cleaner.state.floatbank8_d_air                                    0.339843
# primary_cleaner.state.floatbank8_d_level                                  0.066074
# rougher.input.feed_ag                                                     0.180073
# rougher.input.feed_pb                                                     0.047150
# rougher.input.feed_rate                                                  -0.111722
# rougher.input.feed_size                                                   0.084974
# rougher.input.feed_sol                                                    0.064008
# rougher.input.feed_au                                                     0.100537
# rougher.input.floatbank10_sulfate                                        -0.070671
# rougher.input.floatbank10_xanthate                                        0.024103
# rougher.input.floatbank11_sulfate                                        -0.128733
# rougher.input.floatbank11_xanthate                                       -0.026142
# rougher.output.recovery                                                   0.250908
# rougher.state.floatbank10_a_air                                           0.455357
# rougher.state.floatbank10_a_level                                         0.318341
# rougher.state.floatbank10_b_air                                           0.159601
# rougher.state.floatbank10_b_level                                         0.300313
# rougher.state.floatbank10_c_air                                           0.109546
# rougher.state.floatbank10_c_level                                         0.288652
# rougher.state.floatbank10_d_air                                           0.120555
# rougher.state.floatbank10_d_level                                         0.288772
# rougher.state.floatbank10_e_air                                           0.200919
# rougher.state.floatbank10_e_level                                         0.297515
# rougher.state.floatbank10_f_air                                           0.232740
# rougher.state.floatbank10_f_level                                         0.297358
# secondary_cleaner.state.floatbank2_a_air                                  0.277777
# secondary_cleaner.state.floatbank2_a_level                               -0.086164
# secondary_cleaner.state.floatbank2_b_air                                  0.290658
# secondary_cleaner.state.floatbank2_b_level                               -0.059056
# secondary_cleaner.state.floatbank3_a_air                                  0.476126
# secondary_cleaner.state.floatbank3_a_level                                0.288803
# secondary_cleaner.state.floatbank3_b_air                                  0.342854
# secondary_cleaner.state.floatbank3_b_level                               -0.001730
# secondary_cleaner.state.floatbank4_a_air                                  0.582852
# secondary_cleaner.state.floatbank4_a_level                                0.321067
# secondary_cleaner.state.floatbank4_b_air                                  0.581963
# secondary_cleaner.state.floatbank4_b_level                                0.209011
# secondary_cleaner.state.floatbank5_a_air                                  0.582722
# secondary_cleaner.state.floatbank5_a_level                                0.225148
# secondary_cleaner.state.floatbank5_b_air                                  0.545650
# secondary_cleaner.state.floatbank5_b_level                                0.226735
# secondary_cleaner.state.floatbank6_a_air                                  0.269712
# secondary_cleaner.state.floatbank6_a_level                                0.040620
#
#                                             ...  \
# final.output.recovery                       ...
# primary_cleaner.input.sulfate               ...
# primary_cleaner.input.depressant            ...
# primary_cleaner.input.feed_size             ...
# primary_cleaner.input.xanthate              ...
# primary_cleaner.state.floatbank8_a_air      ...
# primary_cleaner.state.floatbank8_a_level    ...
# primary_cleaner.state.floatbank8_b_air      ...
# primary_cleaner.state.floatbank8_b_level    ...
# primary_cleaner.state.floatbank8_c_air      ...
# primary_cleaner.state.floatbank8_c_level    ...
# primary_cleaner.state.floatbank8_d_air      ...
# primary_cleaner.state.floatbank8_d_level    ...
# rougher.input.feed_ag                       ...
# rougher.input.feed_pb                       ...
# rougher.input.feed_rate                     ...
# rougher.input.feed_size                     ...
# rougher.input.feed_sol                      ...
# rougher.input.feed_au                       ...
# rougher.input.floatbank10_sulfate           ...
# rougher.input.floatbank10_xanthate          ...
# rougher.input.floatbank11_sulfate           ...
# rougher.input.floatbank11_xanthate          ...
# rougher.output.recovery                     ...
# rougher.state.floatbank10_a_air             ...
# rougher.state.floatbank10_a_level           ...
# rougher.state.floatbank10_b_air             ...
# rougher.state.floatbank10_b_level           ...
# rougher.state.floatbank10_c_air             ...
# rougher.state.floatbank10_c_level           ...
# rougher.state.floatbank10_d_air             ...
# rougher.state.floatbank10_d_level           ...
# rougher.state.floatbank10_e_air             ...
# rougher.state.floatbank10_e_level           ...
# rougher.state.floatbank10_f_air             ...
# rougher.state.floatbank10_f_level           ...
# secondary_cleaner.state.floatbank2_a_air    ...
# secondary_cleaner.state.floatbank2_a_level  ...
# secondary_cleaner.state.floatbank2_b_air    ...
# secondary_cleaner.state.floatbank2_b_level  ...
# secondary_cleaner.state.floatbank3_a_air    ...
# secondary_cleaner.state.floatbank3_a_level  ...
# secondary_cleaner.state.floatbank3_b_air    ...
# secondary_cleaner.state.floatbank3_b_level  ...
# secondary_cleaner.state.floatbank4_a_air    ...
# secondary_cleaner.state.floatbank4_a_level  ...
# secondary_cleaner.state.floatbank4_b_air    ...
# secondary_cleaner.state.floatbank4_b_level  ...
# secondary_cleaner.state.floatbank5_a_air    ...
# secondary_cleaner.state.floatbank5_a_level  ...
# secondary_cleaner.state.floatbank5_b_air    ...
# secondary_cleaner.state.floatbank5_b_level  ...
# secondary_cleaner.state.floatbank6_a_air    ...
# secondary_cleaner.state.floatbank6_a_level  ...
#
#                                             secondary_cleaner.state.floatbank4_a_air  \
# final.output.recovery                                                       0.232027
# ...
# secondary_cleaner.state.floatbank3_a_air                                    0.754395
# secondary_cleaner.state.floatbank3_a_level                                  0.163014
# secondary_cleaner.state.floatbank3_b_air                                    0.633538
# secondary_cleaner.state.floatbank3_b_level                                 -0.323532
# secondary_cleaner.state.floatbank4_a_air                                    0.720270
# secondary_cleaner.state.floatbank4_a_level                                  0.238355
# secondary_cleaner.state.floatbank4_b_air                                    0.880369
# secondary_cleaner.state.floatbank4_b_level                                  0.155214
# secondary_cleaner.state.floatbank5_a_air                                    0.891017
# secondary_cleaner.state.floatbank5_a_level                                  0.028070
# secondary_cleaner.state.floatbank5_b_air                                    1.000000
# secondary_cleaner.state.floatbank5_b_level                                  0.040192
# secondary_cleaner.state.floatbank6_a_air                                    0.460943
# secondary_cleaner.state.floatbank6_a_level                                 -0.034936
#
#                                             secondary_cleaner.state.floatbank5_b_level  \
# final.output.recovery                                                         0.047039
# primary_cleaner.input.sulfate                                                -0.035560
# primary_cleaner.input.depressant                                             -0.156878
# primary_cleaner.input.feed_size                                               0.128223
# primary_cleaner.input.xanthate                                               -0.203699
# primary_cleaner.state.floatbank8_a_air                                        0.251556
# primary_cleaner.state.floatbank8_a_level                                      0.081126
# primary_cleaner.state.floatbank8_b_air                                        0.259320
# primary_cleaner.state.floatbank8_b_level                                      0.094091
# primary_cleaner.state.floatbank8_c_air                                        0.226735
# primary_cleaner.state.floatbank8_c_level                                      0.088950
# primary_cleaner.state.floatbank8_d_air                                        0.061164
# primary_cleaner.state.floatbank8_d_level                                      0.010704
# rougher.input.feed_ag                                                         0.154552
# rougher.input.feed_pb                                                         0.018923
# rougher.input.feed_rate                                                      -0.273412
# rougher.input.feed_size                                                      -0.064113
# rougher.input.feed_sol                                                       -0.121916
# rougher.input.feed_au                                                         0.167859
# rougher.input.floatbank10_sulfate                                             0.009916
# rougher.input.floatbank10_xanthate                                           -0.172943
# rougher.input.floatbank11_sulfate                                            -0.043207
# rougher.input.floatbank11_xanthate                                           -0.176444
# rougher.output.recovery                                                      -0.003618
# rougher.state.floatbank10_a_air                                               0.030832
# rougher.state.floatbank10_a_level                                            -0.111836
# rougher.state.floatbank10_b_air                                               0.319893
# rougher.state.floatbank10_b_level                                             0.437834
# rougher.state.floatbank10_c_air                                               0.314604
# rougher.state.floatbank10_c_level                                             0.452505
# rougher.state.floatbank10_d_air                                               0.242649
# rougher.state.floatbank10_d_level                                             0.452210
# rougher.state.floatbank10_e_air                                               0.134255
# rougher.state.floatbank10_e_level                                             0.450120
# rougher.state.floatbank10_f_air                                               0.110183
# rougher.state.floatbank10_f_level                                             0.449582
# secondary_cleaner.state.floatbank2_a_air                                     -0.125137
# secondary_cleaner.state.floatbank2_a_level                                    0.078795
# secondary_cleaner.state.floatbank2_b_air                                     -0.208737
# secondary_cleaner.state.floatbank2_b_level                                    0.093125
# secondary_cleaner.state.floatbank3_a_air                                      0.002142
# secondary_cleaner.state.floatbank3_a_level                                    0.653879
# secondary_cleaner.state.floatbank3_b_air                                     -0.041033
# secondary_cleaner.state.floatbank3_b_level                                    0.544878
# secondary_cleaner.state.floatbank4_a_air                                      0.109637
# secondary_cleaner.state.floatbank4_a_level                                    0.760018
# secondary_cleaner.state.floatbank4_b_air                                      0.029597
# secondary_cleaner.state.floatbank4_b_level                                    0.530527
# secondary_cleaner.state.floatbank5_a_air                                      0.094548
# secondary_cleaner.state.floatbank5_a_level                                    0.895455
# secondary_cleaner.state.floatbank5_b_air                                      0.040192
# secondary_cleaner.state.floatbank5_b_level                                    1.000000
# secondary_cleaner.state.floatbank6_a_air                                      0.499972
# secondary_cleaner.state.floatbank6_a_level                                    0.349034
#
#                                             secondary_cleaner.state.floatbank6_a_air  \
# final.output.recovery                                                      -0.015535
# primary_cleaner.input.sulfate                                              -0.109835
# primary_cleaner.input.depressant                                           -0.167633
# primary_cleaner.input.feed_size                                             0.150701
# primary_cleaner.input.xanthate                                             -0.222071
# primary_cleaner.state.floatbank8_a_air                                      0.305451
# primary_cleaner.state.floatbank8_a_level                                    0.171686
# primary_cleaner.state.floatbank8_b_air                                      0.306476
# primary_cleaner.state.floatbank8_b_level                                    0.166693
# primary_cleaner.state.floatbank8_c_air                                      0.269712
# primary_cleaner.state.floatbank8_c_level                                    0.161789
# primary_cleaner.state.floatbank8_d_air                                      0.021491
# primary_cleaner.state.floatbank8_d_level                                    0.064179
# rougher.input.feed_ag                                                       0.039591
# rougher.input.feed_pb                                                      -0.048388
# rougher.input.feed_rate                                                    -0.306643
# rougher.input.feed_size                                                    -0.143532
# rougher.input.feed_sol                                                     -0.144670
# rougher.input.feed_au                                                       0.063139
# rougher.input.floatbank10_sulfate                                          -0.048200
# rougher.input.floatbank10_xanthate                                         -0.315723
# rougher.input.floatbank11_sulfate                                          -0.091602
# rougher.input.floatbank11_xanthate                                         -0.295852
# rougher.output.recovery                                                    -0.123735
# rougher.state.floatbank10_a_air                                            -0.002720
# rougher.state.floatbank10_a_level                                          -0.216444
# rougher.state.floatbank10_b_air                                             0.401696
# rougher.state.floatbank10_b_level                                           0.455832
# rougher.state.floatbank10_c_air                                             0.436688
# rougher.state.floatbank10_c_level                                           0.456476
# rougher.state.floatbank10_d_air                                             0.407367
# rougher.state.floatbank10_d_level                                           0.456589
# rougher.state.floatbank10_e_air                                             0.219824
# rougher.state.floatbank10_e_level                                           0.462568
# rougher.state.floatbank10_f_air                                             0.249658
# rougher.state.floatbank10_f_level                                           0.467518
# secondary_cleaner.state.floatbank2_a_air                                   -0.043825
# secondary_cleaner.state.floatbank2_a_level                                 -0.057900
# secondary_cleaner.state.floatbank2_b_air                                   -0.043822
# secondary_cleaner.state.floatbank2_b_level                                 -0.036437
# secondary_cleaner.state.floatbank3_a_air                                    0.345228
# secondary_cleaner.state.floatbank3_a_level                                  0.498852
# secondary_cleaner.state.floatbank3_b_air                                    0.375834
# secondary_cleaner.state.floatbank3_b_level                                  0.184942
# secondary_cleaner.state.floatbank4_a_air                                    0.192518
# secondary_cleaner.state.floatbank4_a_level                                  0.567521
# secondary_cleaner.state.floatbank4_b_air                                    0.299563
# secondary_cleaner.state.floatbank4_b_level                                  0.274985
# secondary_cleaner.state.floatbank5_a_air                                    0.423721
# secondary_cleaner.state.floatbank5_a_level                                  0.512538
# secondary_cleaner.state.floatbank5_b_air                                    0.460943
# secondary_cleaner.state.floatbank5_b_level                                  0.499972
# secondary_cleaner.state.floatbank6_a_air                                    1.000000
# secondary_cleaner.state.floatbank6_a_level                                  0.098757
#
#                                             secondary_cleaner.state.floatbank6_a_level
# final.output.recovery                                                        -0.051609
# primary_cleaner.input.sulfate                                                -0.153506
# primary_cleaner.input.depressant                                             -0.131402
# primary_cleaner.input.feed_size                                               0.063868
# primary_cleaner.input.xanthate                                               -0.080971
# primary_cleaner.state.floatbank8_a_air                                        0.054051
# primary_cleaner.state.floatbank8_a_level                                      0.188921
# primary_cleaner.state.floatbank8_b_air                                        0.032635
# primary_cleaner.state.floatbank8_b_level                                      0.194177
# primary_cleaner.state.floatbank8_c_air                                        0.040620
# primary_cleaner.state.floatbank8_c_level                                      0.188983
# primary_cleaner.state.floatbank8_d_air                                       -0.120063
# primary_cleaner.state.floatbank8_d_level                                      0.173671
# rougher.input.feed_ag                                                        -0.116296
# rougher.input.feed_pb                                                        -0.123994
# rougher.input.feed_rate                                                       0.018233
# rougher.input.feed_size                                                       0.074914
# rougher.input.feed_sol                                                       -0.033925
# rougher.input.feed_au                                                        -0.166528
# rougher.input.floatbank10_sulfate                                            -0.039927
# rougher.input.floatbank10_xanthate                                            0.003297
# rougher.input.floatbank11_sulfate                                            -0.052800
# rougher.input.floatbank11_xanthate                                           -0.005174
# rougher.output.recovery                                                      -0.083087
# rougher.state.floatbank10_a_air                                              -0.023786
# rougher.state.floatbank10_a_level                                             0.100907
# rougher.state.floatbank10_b_air                                               0.161697
# rougher.state.floatbank10_b_level                                             0.183691
# rougher.state.floatbank10_c_air                                               0.134408
# rougher.state.floatbank10_c_level                                             0.182472
# rougher.state.floatbank10_d_air                                               0.135634
# rougher.state.floatbank10_d_level                                             0.183969
# rougher.state.floatbank10_e_air                                               0.193409
# rougher.state.floatbank10_e_level                                             0.175618
# rougher.state.floatbank10_f_air                                               0.200072
# rougher.state.floatbank10_f_level                                             0.173051
# secondary_cleaner.state.floatbank2_a_air                                     -0.000018
# secondary_cleaner.state.floatbank2_a_level                                    0.092013
# secondary_cleaner.state.floatbank2_b_air                                     -0.057234
# secondary_cleaner.state.floatbank2_b_level                                    0.086565
# secondary_cleaner.state.floatbank3_a_air                                     -0.036507
# secondary_cleaner.state.floatbank3_a_level                                    0.297945
# secondary_cleaner.state.floatbank3_b_air                                     -0.060367
# secondary_cleaner.state.floatbank3_b_level                                    0.295194
# secondary_cleaner.state.floatbank4_a_air                                     -0.009581
# secondary_cleaner.state.floatbank4_a_level                                    0.262049
# secondary_cleaner.state.floatbank4_b_air                                     -0.115321
# secondary_cleaner.state.floatbank4_b_level                                    0.283154
# secondary_cleaner.state.floatbank5_a_air                                     -0.012258
# secondary_cleaner.state.floatbank5_a_level                                    0.379906
# secondary_cleaner.state.floatbank5_b_air                                     -0.034936
# secondary_cleaner.state.floatbank5_b_level                                    0.349034
# secondary_cleaner.state.floatbank6_a_air                                      0.098757
# secondary_cleaner.state.floatbank6_a_level                                    1.000000
#
# [54 rows x 54 columns]

# %%
def features_choice(data, name_cols, col):
    k = 0
    new = name_cols
    for i in list(name_cols):
        if (abs(data[col].corr(data[i])) > 0.85) and (col != i):
            k += 1
            print('Корреляция', col, '______', i, '=', data[col].corr(data[i]))
            cols_drop.append(col)
            new = name_cols.drop(col)
            return new
    return new

# %%
train_new_col = train_new.drop(['date'], axis=1)
print('Количество признаков до:', len(train_new_col.columns))
k = 0
cols_drop = []
name_cols = train_new_col.columns
for col in list(train_new_col.columns):
    if (col != 'final.output.recovery') and (col != 'rougher.output.recovery'):
        name_cols = features_choice(train_new_col, name_cols, col)

name_cols
# Out:
# Количество признаков до: 54
# Корреляция primary_cleaner.state.floatbank8_a_air ______ primary_cleaner.state.floatbank8_b_air = 0.9447497075406712
# Корреляция primary_cleaner.state.floatbank8_a_level ______ primary_cleaner.state.floatbank8_b_level = 0.9776228372304803
# Корреляция primary_cleaner.state.floatbank8_b_air ______ primary_cleaner.state.floatbank8_c_air = 0.9401440095663035
# Корреляция primary_cleaner.state.floatbank8_b_level ______ primary_cleaner.state.floatbank8_c_level = 0.9673596077063681
# Корреляция rougher.input.floatbank10_xanthate ______ rougher.input.floatbank11_xanthate = 0.8935613807910262
# Корреляция rougher.state.floatbank10_b_air ______ rougher.state.floatbank10_c_air = 0.9345541349477985
# Корреляция rougher.state.floatbank10_b_level ______ rougher.state.floatbank10_c_level = 0.9876282997462964
# Корреляция rougher.state.floatbank10_c_air ______ rougher.state.floatbank10_d_air = 0.9101531681709231
# Корреляция rougher.state.floatbank10_c_level ______ rougher.state.floatbank10_d_level = 0.9875747329396998
# Корреляция rougher.state.floatbank10_d_air ______ rougher.state.floatbank10_e_air = 0.8725989078073135
# Корреляция rougher.state.floatbank10_d_level ______ rougher.state.floatbank10_e_level = 0.9774000961926294
# Корреляция rougher.state.floatbank10_e_air ______ rougher.state.floatbank10_f_air = 0.9331166268313278
# Корреляция rougher.state.floatbank10_e_level ______ rougher.state.floatbank10_f_level = 0.9896775587873304
# Корреляция secondary_cleaner.state.floatbank2_a_air ______ secondary_cleaner.state.floatbank2_b_air = 0.8772889195690673
# Корреляция secondary_cleaner.state.floatbank2_a_level ______ secondary_cleaner.state.floatbank2_b_level = 0.9029809030755479
# Корреляция secondary_cleaner.state.floatbank4_b_air ______ secondary_cleaner.state.floatbank5_b_air = 0.880369146449377
# Корреляция secondary_cleaner.state.floatbank5_a_air ______ secondary_cleaner.state.floatbank5_b_air = 0.8910166821602805
# Корреляция secondary_cleaner.state.floatbank5_a_level ______ secondary_cleaner.state.floatbank5_b_level = 0.8954550509949072
# Index(['final.output.recovery', 'primary_cleaner.input.sulfate',
#        'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
#        'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.output.recovery',
#        'rougher.state.floatbank10_a_air', 'rougher.state.floatbank10_a_level',
#        'rougher.state.floatbank10_f_air', 'rougher.state.floatbank10_f_level',
#        'secondary_cleaner.state.floatbank2_b_air',
#        'secondary_cleaner.state.floatbank2_b_level',
#        'secondary_cleaner.state.floatbank3_a_air',
#        'secondary_cleaner.state.floatbank3_a_level',
#        'secondary_cleaner.state.floatbank3_b_air',
#        'secondary_cleaner.state.floatbank3_b_level',
#        'secondary_cleaner.state.floatbank4_a_air',
#        'secondary_cleaner.state.floatbank4_a_level',
#        'secondary_cleaner.state.floatbank4_b_level',
#        'secondary_cleaner.state.floatbank5_b_air',
#        'secondary_cleaner.state.floatbank5_b_level',
#        'secondary_cleaner.state.floatbank6_a_air',
#        'secondary_cleaner.state.floatbank6_a_level'],
#       dtype='object')

# %%
train_new_col = train_new[name_cols]
test_new = test[name_cols]
train_new_col.shape
# Out:
# (13600, 36)

# %% [markdown]
# Осталось 36 колонок, из которых 2 признака целевые.

# %% [markdown]
# ### Вывод
#
# На этом этапе были проанализированы данные исходной, тренировочной и тестовой выборок. Концентрация золота растет от этапа к этапу, чего нельзя сказать об остальных металлах. Размеры гранул сырья в тренировочной и тестовой выбрках распределены одинаковым образом. Найденные аномалии и выбросы в распределении концентрации металлов и оценки качества очистки были удалены.

# %% [markdown]
# ## Модель

# %% [markdown]
# Напишем функции для подсчета sMAPE.

# %%
def smape(y, y1):
    return (1 / len(y) * sum(abs(y - y1) / (abs(y) + abs(y1)) * 2 * 100))

def smape_fin(target, pred):
    target = np.array(target)
    pred = np.array(pred)
    return 0.25 * smape(target[:, 0], pred[:, 0]) + 0.75 * smape(target[:, 1], pred[:, 1])

# %% [markdown]
# Напишем скорер для кроссвалидации.

# %%
smape_score = make_scorer(smape_fin, greater_is_better=False)

# %% [markdown]
# Выделим признаки и целевые признаки для тренировочной и тестовой выборок.

# %%
target_train = train_new_col[['rougher.output.recovery', 'final.output.recovery']]
features_train = train_new_col.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
target_test = test_new[['rougher.output.recovery', 'final.output.recovery']]
features_test = test_new.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)

# %%
features_test.shape
# Out:
# (5232, 34)

# %% [markdown]
# ### Линейная регрессия

# %%
lin = LinearRegression()
final_score = cross_val_score(lin, features_train, target_train, cv=3, scoring=smape_score).mean()
print('sMAPE линейной регрессии: {:.3f}'.format(final_score))
# Out:
# sMAPE линейной регрессии: -12.391

# %% [markdown]
# ### Случайный лес

# %%
smape_best = 100
depth_best = 0
for depth in range(6, 10):
    forest = RandomForestRegressor(random_state=123, n_estimators=10, max_depth=depth)
    final_score = (cross_val_score(forest, features_train, target_train, cv=3, scoring=smape_score).mean())
    if abs(final_score) < abs(smape_best):
        smape_best = final_score
        depth_best = depth
            
print('Глубина: ', depth_best)
print('sMAPE: {:.3f}'.format(smape_best))
# Out:
# Глубина:  6
# sMAPE: -10.266

# %%
smape_best = 100
est_best = 0
for est in range(10, 50, 10):
    forest = RandomForestRegressor(random_state=123, n_estimators=est, max_depth=depth_best)
    final_score = (cross_val_score(forest, features_train, target_train, cv=3, scoring=smape_score).mean())
    if abs(final_score) < abs(smape_best):
        smape_best = final_score
        est_best = est

print('Количество деревьев:', est_best)
print('sMAPE: {:.3f}'.format(smape_best))
# Out:
# Количество деревьев: 40
# sMAPE: -9.928

# %%
print('Случайный лес')
print('Глубина:', depth_best)
print('Количество деревьев:', est_best)
print('sMAPE: {:.3f}'.format(smape_best))
# Out:
# Случайный лес
# Глубина: 6
# Количество деревьев: 40
# sMAPE: -9.928

# %% [markdown]
# ### Градиентный бустинг

# %%
smape_best = 100
depth_best = 0
for depth in range(3, 6):
    gb = GradientBoostingRegressor(loss='lad', random_state=123, n_estimators=10, max_depth=depth, learning_rate=0.01)
    final_score = cross_val_score(gb, features_train, target_train.iloc[:, 1], cv=3,
                                  scoring=make_scorer(smape, greater_is_better=False)).mean()
    rougher_score = cross_val_score(gb, features_train, target_train.iloc[:, 0], cv=3,
                                    scoring=make_scorer(smape, greater_is_better=False)).mean()
    sm = 0.25 * rougher_score + 0.75 * final_score
    if abs(sm) < abs(smape_best):
        smape_best = sm
        depth_best = depth
            
print('Глубина:', depth_best)
print('sMAPE: {:.3f}'.format(smape_best))
# Out:
# Глубина: 4
# sMAPE: -10.053

# %%
smape_best = 100
est_best = 0
for est in range(20, 60, 20):
    gb = GradientBoostingRegressor(loss='lad', random_state=123, n_estimators=est, max_depth=depth_best, learning_rate=0.01)
    final_score = cross_val_score(gb, features_train, target_train.iloc[:, 1], cv=3,
                                  scoring=make_scorer(smape, greater_is_better=False)).mean()
    rougher_score = cross_val_score(gb, features_train, target_train.iloc[:, 0], cv=3,
                                    scoring=make_scorer(smape, greater_is_better=False)).mean()
    sm = 0.25 * rougher_score + 0.75 * final_score
    if abs(sm) < abs(smape_best):
        smape_best = sm
        est_best = est

print('Количество деревьев:', est_best)
print('sMAPE: {:.3f}'.format(smape_best))
# Out:
# Количество деревьев: 40
# sMAPE: -9.790

# %%
smape_best = 100
best_rate = 0
for rate in np.arange(0.01, 0.06, 0.01):
    gb = GradientBoostingRegressor(loss='lad', random_state=123, n_estimators=est_best, max_depth=depth_best, learning_rate=rate)
    final_score = cross_val_score(gb, features_train, target_train.iloc[:, 1], cv=3,
                                  scoring=make_scorer(smape, greater_is_better=False)).mean()
    rougher_score = cross_val_score(gb, features_train, target_train.iloc[:, 0], cv=3,
                                    scoring=make_scorer(smape, greater_is_better=False)).mean()
    sm = 0.25 * rougher_score + 0.75 * final_score
    if abs(sm) < abs(smape_best):
        smape_best = sm
        best_rate = rate
        
print('Лучший rate:', best_rate)
print('sMAPE: {:.3f}'.format(smape_best))
# Out:
# Лучший rate: 0.04
# sMAPE: -9.441

# %%
print('Градиентный бустинг')
print('Глубина:', depth_best)
print('Количество деревьев:', est_best)
print('Лучший rate:', best_rate)
print('sMAPE: {:.3f}'.format(smape_best))
# Out:
# Градиентный бустинг
# Глубина: 4
# Количество деревьев: 40
# Лучший rate: 0.04
# sMAPE: -9.441

# %% [markdown]
# Лучшей моделью по sMAPE является ***Градиентный бустинг***.

# %% [markdown]
# ### Тестирование
#
# Протестируем лучшую модель на тестовой выборке

# %%
model = GradientBoostingRegressor(loss='lad', random_state=123, n_estimators=est_best, max_depth=depth_best, learning_rate=rate)
model_final = model.fit(features_train, target_train['final.output.recovery'])
model = GradientBoostingRegressor(loss='lad', random_state=123, n_estimators=est_best, max_depth=depth_best, learning_rate=rate)
model_rougher = model.fit(features_train, target_train['rougher.output.recovery'])

predictions_final = model_final.predict(features_test)
predictions_rougher = model_rougher.predict(features_test)
final_score = smape(target_test['final.output.recovery'], predictions_final)
rougher_score = smape(target_test['rougher.output.recovery'], predictions_rougher)
sm = 0.25 * rougher_score + 0.75 * final_score
print('Результирующее sMAPE лучшей модели: {:.3f}'.format(sm))
# Out:
# Результирующее sMAPE лучшей модели: 7.033

# %% [markdown]
# Результаты даже лучше чем на тренировочной. Но для того, чтоб убедиться в адекватности модели сравним ее с Dummy регрессором.

# %% [markdown]
# ### Проверка на адекватность

# %%
dummy = DummyRegressor()
dummy_final = dummy.fit(features_train, target_train['final.output.recovery'])
dummy = DummyRegressor()
dummy_rougher = dummy.fit(features_train, target_train['rougher.output.recovery'])

predictions_final = dummy_final.predict(features_test)
predictions_rougher = dummy_rougher.predict(features_test)
final_score = smape(target_test['final.output.recovery'], predictions_final)
rougher_score = smape(target_test['rougher.output.recovery'], predictions_rougher)
sm = 0.25 * rougher_score + 0.75 * final_score
print('sMAPE Dummy-регрессора: {:.3f}'.format(sm))
# Out:
# sMAPE Dummy-регрессора: 8.132

# %% [markdown]
# ## Вывод
#
# 1)  В первом разделе был произведен расчет средней абсолютной ошибки МАЕ и она оказалась близка к 0, что говорит о том, что представленные данные полностью соответствуют теоретическим расчетамы эффективности обогащения золотосодержащей руды. Так же была произведена предобработка данных, а именно были заполнены пропуски, в тестовую выборку были добавлены целевые признаки и в тренировочной выборке оставили только те признаки, которые есть в тестовой.
#
# 2) Во втором разделе выяснилось, что концентрация золота растет от этапа к этапу, чего нельзя сказать об остальных металлах. Размеры гранул сырья в тренировочной и тестовой выбрках распределены одинаковым образом.
#
# 3) Лучше всех на тренировочной выборке себя показала модель Градиентного бустинга, а на тестовой выборке подтвердила свою эффективность и прошла проверку на адекватность.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке выполнения
# - [x]  Выполнен шаг 1: данные подготовлены
#     - [x]  Проверена формула вычисления эффективности обогащения
#     - [x]  Проанализированы признаки, недоступные в тестовой выборке
#     - [x]  Проведена предобработка данных
# - [x]  Выполнен шаг 2: данные проанализированы
#     - [x]  Исследовано изменение концентрации элементов на каждом этапе
#     - [x]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [x]  Исследованы суммарные концентрации
#     - [x]  Проанализированы и обработаны аномальные значения
# - [x]  Выполнен шаг 3: построена модель прогнозирования
#     - [x]  Написана функция для вычисления итогового *sMAPE*
#     - [x]  Обучено и проверено несколько моделей
#     - [x]  Выбрана лучшая модель, её качество проверено на тестовой выборке
